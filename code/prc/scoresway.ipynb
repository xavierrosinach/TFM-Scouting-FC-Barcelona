# %%
import pandas as pd
import os
import json as jsonlib
from typing import Tuple

# Obtenemos el CSV con competiciones
cdir = os.getcwd()
utils = os.path.join(os.path.abspath(os.path.join(cdir, '..', '..')), 'utils')
comps = pd.read_csv(os.path.join(utils, 'comps.csv'), sep=';')

# JSON con temporadas deseadas
with open(os.path.join(utils, 'des_seasons.json'), 'r', encoding='utf-8') as f:
    desired_seasons = jsonlib.load(f)

# Lector de JSON
def json_to_dict(json_path: str) -> dict:
    with open(json_path, "r", encoding="utf-8") as f:
        dict = jsonlib.load(f)
    return dict

# %%
# Procesado del json de información sobre los partidos
def matches_processing(matches_path: str) -> pd.DataFrame:

    # JSON
    matches_json = json_to_dict(json_path=matches_path)

    # Lista para concatenar información
    match_info_list = []

    for match in matches_json.get('match', []):

        # Información del partido
        single_match_info = match.get('matchInfo', {})
        single_match_live_data = match.get('liveData', {})

        # Añadimos la info al diccionario
        match_info_list.append({'id': single_match_info.get('id', ''),
                                'slug': f'{single_match_info.get('contestant')[0].get('code', '').lower()}-{single_match_info.get('contestant')[1].get('code', '').lower()}',
                                'date': single_match_info.get('date', ''),
                                'time': single_match_info.get('time', ''),
                                'home_team': single_match_info.get('contestant')[0].get('officialName', ''),
                                'away_team': single_match_info.get('contestant')[1].get('officialName', ''),
                                'venue': single_match_info.get('venue', {}).get('longName', ''),
                                'attendance': single_match_live_data.get('matchDetailsExtra', {}).get('attendance', 0),
                                'match_min': single_match_live_data.get('matchDetails', {}).get('matchLengthMin', 90),
                                'first_half_min': single_match_live_data.get('matchDetails', {}).get('period', [])[0].get('lengthMin', 45),
                                'second_half_min': single_match_live_data.get('matchDetails', {}).get('period', [])[1].get('lengthMin', 45),
                                'home_score_ht': single_match_live_data.get('matchDetails', {}).get('scores', {}).get('ht', {}).get('home', 0),
                                'away_score_ht': single_match_live_data.get('matchDetails', {}).get('scores', {}).get('ht', {}).get('away', 0),
                                'home_score_ft': single_match_live_data.get('matchDetails', {}).get('scores', {}).get('ft', {}).get('home', 0),
                                'away_score_ft': single_match_live_data.get('matchDetails', {}).get('scores', {}).get('ft', {}).get('away', 0),
                                'referee': f'{single_match_live_data.get('matchDetailsExtra', {}).get('matchOfficial')[0].get('firstName', '')} {single_match_live_data.get('matchDetailsExtra', {}).get('matchOfficial')[0].get('lastName', '')}'})
        
    return pd.DataFrame(match_info_list)
    
# Función para el procesado de las plantillas de una liga
def squads_processing(squads_path: str) -> Tuple[pd.DataFrame, pd.DataFrame, pd.DataFrame]:

    # JSON
    squads_json = json_to_dict(json_path=squads_path)
    squads_info = squads_json.get('squad')

    # Lista con la info de los equipos y jugadores
    info_teams = []
    info_players = []
    info_managers = []

    # Para cada equipo
    for squad in squads_info:
        # Concatenamos información
        info_teams.append({'id':squad.get('contestantId', ''),
                        'code': squad.get('contestantCode', ''),
                        'slug': squad.get('contestantCode', '').lower(),
                        'name': squad.get('contestantName', ''),
                        'club_name': squad.get('contestantClubName', ''),
                        'short_name': squad.get('contestantShortName', ''),
                        'venue': squad.get('venueName', '')})

        squad_name = squad.get('contestantName', '')

        # Concatenamos jugadores y entrenadores
        for player in squad.get('person', []):
            first_name = player.get('firstName', '')
            last_name = player.get('lastName', '')
            
            # Appendamos la info de jugadores solo si estan en activo
            if player.get('type', '') == 'player' and player.get('shirtNumber'):
                info_players.append({'id': player.get('id', ''),
                                    'name': f'{first_name} {last_name}',
                                    'short_name': f'{player.get('shortFirstName', '')} {player.get('shortLastName', '')}',
                                    'match_name': player.get('matchName', ''),
                                    'first_name': first_name,
                                    'last_name': last_name,
                                    'team': squad_name,
                                    'nationality': player.get('nationality', ''),
                                    'position': player.get('position', ''),
                                    'shirt_number': player.get('shirtNumber', '')})
            elif player.get('type', '') != 'player':       # Entrenador
                info_managers.append({'id': player.get('id', ''),
                                    'name': f'{first_name} {last_name}',
                                    'short_name': f'{player.get('shortFirstName', '')} {player.get('shortLastName', '')}',
                                    'match_name': player.get('matchName', ''),
                                    'first_name': first_name,
                                    'last_name': last_name,
                                    'team': squad_name,
                                    'nationality': player.get('nationality', ''),
                                    'type': player.get('type', '')})

    return pd.DataFrame(info_teams), pd.DataFrame(info_players), pd.DataFrame(info_managers)

# Función para obtener las tablas de clasificación de distintos tipos
def standings_processing(standings_path: str) -> Tuple[pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame]: 

    # Función parcial
    def part_standings_table(standings_dict: dict, type: str) -> pd.DataFrame:

        # Ir añadiendo información
        list_info = []

        for team in standings_dict:
            if type == 'total':
                list_info.append({'rank': team.get('rank', 0),
                                'status': team.get('rankStatus', ''),
                                'team': team.get('contestantName', ''),
                                'points': team.get('points', 0),
                                'matches_played': team.get('matchesPlayed', 0),
                                'wins': team.get('matchesWon', 0),
                                'draws': team.get('matchesLost', 0),
                                'losses': team.get('matchesDrawn', 0),
                                'goals_for': team.get('goalsFor', 0),
                                'goals_against': team.get('goalsAgainst', 0)})
            elif type in ['home', 'away', 'half']:
                list_info.append({'rank': team.get('rank', 0),
                                'team': team.get('contestantName', ''),
                                'points': team.get('points', 0),
                                'matches_played': team.get('matchesPlayed', 0),
                                'wins': team.get('matchesWon', 0),
                                'draws': team.get('matchesLost', 0),
                                'losses': team.get('matchesDrawn', 0),
                                'goals_for': team.get('goalsFor', 0),
                                'goals_against': team.get('goalsAgainst', 0)})
            elif type == 'attendance':
                list_info.append({'rank': team.get('rank', 0),
                                'team': team.get('contestantName', ''),
                                'venue_name': team.get('venueName', ''),
                                'min_attendance': team.get('minimumAttendance', 0),
                                'max_attendance': team.get('maximumAttendance', 0),
                                'total_attendance': team.get('totalAttendance', 0),
                                'avg_attendance': team.get('averageAttendance', 0),
                                'capacity': team.get('capacity', 0),
                                'percent_sold': team.get('percentSold', 0)})
        
        return pd.DataFrame(list_info)

    # JSON
    standings_json = json_to_dict(json_path=standings_path)

    # Obtener información
    all_tables = standings_json.get('stage', [])[0].get('division', [])

    # Obtener las cinco tablas diferentes
    total_df = part_standings_table(standings_dict=all_tables[0].get('ranking', []), type='total')
    home_df = part_standings_table(standings_dict=all_tables[1].get('ranking', []), type='home')
    away_df = part_standings_table(standings_dict=all_tables[2].get('ranking', []), type='away')
    half_df = part_standings_table(standings_dict=all_tables[6].get('ranking', []), type='half')
    attendance_df = part_standings_table(standings_dict=all_tables[9].get('ranking', []), type='attendance')

    return total_df, home_df, away_df, half_df, attendance_df

# Función para el procesado de una temporada de una liga
def process_season_info_dfs(raw_data_path: str) -> Tuple[pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame]:

    # Paths de info y de partidos
    info_path = os.path.join(raw_data_path, 'info')

    # Dentro de info encontramos matches, squads y standings
    matches_df = matches_processing(os.path.join(info_path, 'matches.json'))
    teams_df, players_df, managers_df = squads_processing(os.path.join(info_path, 'squads.json'))
    st_total_df, st_home_df, st_away_df, st_half_df, st_attendance_df = standings_processing(os.path.join(info_path, 'standings.json'))

    return matches_df, teams_df, players_df, managers_df, st_total_df, st_home_df, st_away_df, st_half_df, st_attendance_df

# A partir de la alineación de un partido, obtenemos datos de los jguadores (de un solo equipo)
def obtain_team_lineup_df(team_lineup: dict, team_id: str) -> pd.DataFrame:

    # Lista para añadir jugadores
    list_player = []

    for player in team_lineup:
        
        # Información
        player_dict = {'player_id': player.get('playerId', ''), 
                       'name': f'{player.get('firstName', '')} {player.get('lastName', '')}',
                       'short_name': f'{player.get('shortFirstName', '')} {player.get('shortLastName', '')}',
                       'match_name': player.get('matchName', ''),
                       'shirt_number': player.get('shirtNumber', 0),
                       'position': player.get('position', ''),
                       'pos_side': player.get('positionSide', '') if player.get('positionSide') else player.get('subPosition', ''),
                       'formation_place': player.get('formationPlace', 0)}
        
        # Estadísticas
        for stat in player.get('stat', []):
            player_dict[stat.get('type', '')] = stat.get('value', 0)

        # Append
        list_player.append(player_dict)

    # Dataframe
    df = pd.DataFrame(list_player)
    df.insert(0, 'team', team_id)
    df.dropna(subset=['minsPlayed'], inplace=True)

    return df

# Función para obtener los datos de un partido
def obtain_match_data(match_json_path: str) -> Tuple[pd.DataFrame, pd.DataFrame, pd.DataFrame]:

    # JSON
    event_json = json_to_dict(json_path=match_json_path)

    # Información básica que necesitaremos
    match_id = event_json.get('matchInfo', {}).get('id', '')
    match_slug = f'{event_json.get('matchInfo', {}).get('contestant', [])[0].get('code', '').lower()}-{event_json.get('matchInfo', {}).get('contestant', [])[1].get('code', '').lower()}'

    # Obtenemos live data, que es donde hay la información
    match_live_data = event_json.get('liveData', {})

    # Dataframe con los goles del partido
    goals_list = []
    for goal in match_live_data['goal']:
        goals_list.append({'match': match_id,
                           'match_slug': match_slug,
                           'type': goal.get('type', ''), 
                           'team_id': goal.get('contestantId', ''),
                           'minute': goal.get('timeMinSec', ''),
                           'scorer_id': goal.get('scorerId', ''),
                           'scorer': goal.get('scorerName', ''),
                           'assister_id': goal.get('assistPlayerId', ''),
                           'assister': goal.get('assistPlayerName', '')})
    goals_df = pd.DataFrame(goals_list)

    # Obtenemos datos a partir de las alineaciones de los equipos
    home_lineup = match_live_data.get('lineUp', [])[0]
    away_lineup = match_live_data.get('lineUp', [])[1]

    # Obtenemos diccionarios y concatenamos
    teams_dicts = []
    players_stats = []
    for team in [home_lineup, away_lineup]:
        single_team_dict = {'id': team.get('contestantId', ''),
                            'formation': team.get('formationUsed', ''),
                            'manager_id': team.get('teamOfficial', [])[0].get('id', ''), 
                            'manager': f'{team.get('teamOfficial', [])[0].get('firstName', '')} {team.get('teamOfficial', [])[0].get('lastName', '')}',
                            'kit': team.get('kit', {}).get('type'),
                            'kit_col1': team.get('kit', {}).get('colour1'),
                            'kit_col2': team.get('kit', {}).get('colour2')}
        
        # Para cada stat:
        for stat in team.get('stat', []):
            single_team_dict[stat.get('type', '')] = stat.get('value', 0)
        
        # Concatenamos
        teams_dicts.append(single_team_dict)

        # Estadísticas de jugadores
        players_stats.append(obtain_team_lineup_df(team.get('player', []), team_id=team.get('contestantId', '')))

    # Stats de equipos y de los jugadores
    teams_stats_df = pd.DataFrame(teams_dicts).fillna(0)
    players_stats_df = pd.concat(players_stats, ignore_index=True).fillna(0)

    return goals_df, teams_stats_df, players_stats_df

# %%
league_id = 73
raw_out_path = r'C:\Users\xrosinach\Desktop\TFM-Scouting-FC-Barcelona\data\raw'
clean_out_path = r'C:\Users\xrosinach\Desktop\TFM-Scouting-FC-Barcelona\data\clean'

# Obtenemos el nombre de la liga y el path -> creación de la carpeta de output (clean)
league_name = comps[comps['id'] == league_id]['tournament'].iloc[0]
league_slug = league_name.lower().replace(' ', '-')
out_league_path = os.path.join(clean_out_path, 'sw', league_slug)
os.makedirs(out_league_path, exist_ok=True)

# Capeta de la liga y carpetas (seasons) dentro
raw_data_path = os.path.join(raw_out_path, 'sw', league_slug)
seasons_raw = [f for f in os.listdir(raw_data_path) if os.path.isdir(os.path.join(raw_data_path, f))]

# Para cada temporada, procesamos
for season in seasons_raw:

    # Creación de la carpeta de output
    out_season_path = os.path.join(out_league_path, season)
    os.makedirs(out_season_path, exist_ok=True)

    # Obtenemos todos los dataframes
    matches_df, teams_df, players_df, managers_df, st_total_df, st_home_df, st_away_df, st_half_df, st_attendance_df = process_season_info_dfs(raw_data_path=os.path.join(raw_data_path, season))

    # Añadimos liga y temporada
    for df in [matches_df, teams_df, players_df, managers_df, st_total_df, st_home_df, st_away_df, st_half_df, st_attendance_df]:
        df.insert(0, 'league', league_id)
        df.insert(1, 'season', season)

    # Guardado de todos los dataframes en formato CSV
    matches_df.to_csv(os.path.join(out_season_path, 'matches.csv'), sep=';', index=False)
    teams_df.to_csv(os.path.join(out_season_path, 'teams.csv'), sep=';', index=False)
    players_df.to_csv(os.path.join(out_season_path, 'players.csv'), sep=';', index=False)
    managers_df.to_csv(os.path.join(out_season_path, 'managers.csv'), sep=';', index=False)
    st_total_df.to_csv(os.path.join(out_season_path, 'standings_total.csv'), sep=';', index=False)
    st_home_df.to_csv(os.path.join(out_season_path, 'standings_home.csv'), sep=';', index=False)
    st_away_df.to_csv(os.path.join(out_season_path, 'standings_away.csv'), sep=';', index=False)
    st_half_df.to_csv(os.path.join(out_season_path, 'standings_halftime.csv'), sep=';', index=False)
    st_attendance_df.to_csv(os.path.join(out_season_path, 'standings_attendance.csv'), sep=';', index=False)

# %%
season = '2425'

# Path y partidos a procesar
season_raw_path = os.path.join(raw_data_path, season, 'matches')
matches_to_proc = [f for f in os.listdir(season_raw_path) if f.endswith('.json') and os.path.isfile(os.path.join(season_raw_path, f))]

# %%
path = os.path.join(season_raw_path, matches_to_proc[0])
match_live_data, goals_df, teams_stats_df, players_stats_df = obtain_match_data(match_json_path=path)

# %%
match_live_data
# Out:
# {'matchDetails': {'periodId': 14,
#   'matchStatus': 'Played',
#   'winner': 'away',
#   'matchLengthMin': 96,
#   'matchLengthSec': 8,
#   'period': [{'id': 1,
#     'start': '2025-05-25T19:02:51Z',
#     'end': '2025-05-25T19:49:54Z',
#     'lengthMin': 47,
#     'lengthSec': 3,
#     'announcedInjuryTime': 120},
#    {'id': 2,
#     'start': '2025-05-25T20:05:36Z',
#     'end': '2025-05-25T20:54:41Z',
#     'lengthMin': 49,
#     'lengthSec': 5,
#     'announcedInjuryTime': 240}],
#   'scores': {'ht': {'home': 0, 'away': 2},
#    'ft': {'home': 0, 'away': 3},
#    'total': {'home': 0, 'away': 3}}},
#  'goal': [{'contestantId': 'agh9ifb2mw3ivjusgedj7c3fe',
#    'periodId': 1,
#    'timeMin': 14,
#    'timeMinSec': '13:33',
#    'lastUpdated': '2025-09-16T09:24:20Z',
#    'timestamp': '2025-05-25T19:16:25Z',
#    'type': 'G',
#    'scorerId': 'afxjicw89683nlpms9yy5x51x',
#    'scorerName': 'R. Lewandowski',
#    'assistPlayerId': 'cjll1xrw3xulnl23c9tlf6rys',
#    'assistPlayerName': 'Fermín López',
#    'optaEventId': '2819093115',
#    'homeScore': 0,
#    'awayScore': 1},
#   {'contestantId': 'agh9ifb2mw3ivjusgedj7c3fe',
#    'periodId': 1,
#    'timeMin': 18,
#    'timeMinSec': '17:01',
#    'lastUpdated': '2025-09-16T09:24:20Z',
#    'timestamp': '2025-05-25T19:19:52Z',
#    'type': 'G',
#    'scorerId': 'afxjicw89683nlpms9yy5x51x',
#    'scorerName': 'R. Lewandowski',
#    'optaEventId': '2819095873',
#    'homeScore': 0,
#    'awayScore': 2},
#   {'contestantId': 'agh9ifb2mw3ivjusgedj7c3fe',
#    'periodId': 2,
#    'timeMin': 94,
#    'timeMinSec': '93:44',
#    'lastUpdated': '2025-09-16T09:22:19Z',
#    'timestamp': '2025-05-25T20:54:21Z',
#    'type': 'PG',
#    'scorerId': '4gq1u1mqg0qzekh1u5djleeax',
#    'scorerName': 'Dani Olmo',
#    'optaEventId': '2819161777',
#    'homeScore': 0,
#    'awayScore': 3}],
#  'card': [{'contestantId': '3czravw89omgc9o4s0w3l1bg5',
#    'periodId': 2,
#    'timeMin': 75,
#    'timeMinSec': '74:26',
#    'lastUpdated': '2025-05-25T20:35:18Z',
#    'timestamp': '2025-05-25T20:35:03Z',
#    'type': 'YC',
#    'playerId': '8hm6d6395johhjsoe8jz6dcyd',
#    'playerName': 'Yuri',
#    'optaEventId': '2819149735',
#    'cardReason': 'Foul'}],
#  'substitute': [{'contestantId': '3czravw89omgc9o4s0w3l1bg5',
#    'periodId': 2,
#    'timeMin': 62,
#    'timeMinSec': '61:17',
#    'lastUpdated': '2025-05-25T20:22:02Z',
#    'timestamp': '2025-05-25T20:21:54Z',
#    'playerOnId': '352ywlfcjt329s7etjn4rkui2',
#    'playerOnName': 'Beñat Prados',
#    'playerOffId': '7ubtan6a51o79w469zawrqqqd',
#    'playerOffName': 'Íñigo Ruíz de Galarreta',
#    'subReason': 'Tactical'},
#   {'contestantId': '3czravw89omgc9o4s0w3l1bg5',
#    'periodId': 2,
#    'timeMin': 62,
#    'timeMinSec': '61:18',
#    'lastUpdated': '2025-05-25T20:22:07Z',
#    'timestamp': '2025-05-25T20:21:55Z',
#    'playerOnId': 'dfcbvsb7o18lavmonbp5ucwoa',
#    'playerOnName': 'Oihan Sancet',
#    'playerOffId': 'b2rqgjegzeyq6wy6qu63zz2fo',
#    'playerOffName': 'Unai Gómez',
#    'subReason': 'Tactical'},
#   {'contestantId': '3czravw89omgc9o4s0w3l1bg5',
#    'periodId': 2,
#    'timeMin': 62,
#    'timeMinSec': '61:34',
#    'lastUpdated': '2025-08-07T15:22:10Z',
#    'timestamp': '2025-05-25T20:22:10Z',
#    'playerOnId': '9d5h5wxf44qu4fw3jk2pgis16',
#    'playerOnName': 'Dani Vivian',
#    'playerOffId': 'e8s9ssopq5nmp51zymvqp8jbp',
#    'playerOffName': 'Unai Núñez',
#    'subReason': 'Tactical'},
#   {'contestantId': 'agh9ifb2mw3ivjusgedj7c3fe',
#    'periodId': 2,
#    'timeMin': 64,
#    'timeMinSec': '63:29',
#    'lastUpdated': '2025-09-16T09:18:05Z',
#    'timestamp': '2025-05-25T20:24:06Z',
#    'playerOnId': '1av9mmv19jwvc4xdr0p9owyxh',
#    'playerOnName': 'A. Christensen',
#    'playerOffId': 'awsod0zmnrukk21d4882ji7e1',
#    'playerOffName': 'R. Araujo',
#    'subReason': 'Tactical'},
#   {'contestantId': 'agh9ifb2mw3ivjusgedj7c3fe',
#    'periodId': 2,
#    'timeMin': 64,
#    'timeMinSec': '63:32',
#    'lastUpdated': '2025-09-16T09:22:19Z',
#    'timestamp': '2025-05-25T20:24:09Z',
#    'playerOnId': '4gq1u1mqg0qzekh1u5djleeax',
#    'playerOnName': 'Dani Olmo',
#    'playerOffId': '2wl6h1rlrfnn2mr65vuo3t815',
#    'playerOffName': 'Raphinha',
#    'subReason': 'Tactical'},
#   {'contestantId': '3czravw89omgc9o4s0w3l1bg5',
#    'periodId': 2,
#    'timeMin': 80,
#    'timeMinSec': '79:42',
#    'lastUpdated': '2025-05-26T17:52:53Z',
#    'timestamp': '2025-05-25T20:40:19Z',
#    'playerOnId': 'ddvvwqxpsqqboupi3gx1ijhed',
#    'playerOnName': 'I. Williams',
#    'playerOffId': '66jotyvbhtz5cjvhbby6luelm',
#    'playerOffName': 'Nico Williams',
#    'subReason': 'Tactical'},
#   {'contestantId': 'agh9ifb2mw3ivjusgedj7c3fe',
#    'periodId': 2,
#    'timeMin': 81,
#    'timeMinSec': '80:24',
#    'lastUpdated': '2025-09-16T09:20:40Z',
#    'timestamp': '2025-05-25T20:41:01Z',
#    'playerOnId': '6l1y87tlepsvr83d8y2qifeqy',
#    'playerOnName': 'Gerard Martín',
#    'playerOffId': 'bzgh5psb1janz9y3btpswngbu',
#    'playerOffName': 'Alejandro Balde',
#    'subReason': 'Tactical'},
#   {'contestantId': 'agh9ifb2mw3ivjusgedj7c3fe',
#    'periodId': 2,
#    'timeMin': 81,
#    'timeMinSec': '80:34',
#    'lastUpdated': '2025-09-16T09:19:42Z',
#    'timestamp': '2025-05-25T20:41:10Z',
#    'playerOnId': 'ezviixcyaaj162saxs2yl27s9',
#    'playerOnName': 'F. de Jong',
#    'playerOffId': '4ftlhtels58lyzfluwofzwxuy',
#    'playerOffName': 'Pedri',
#    'subReason': 'Tactical'},
#   {'contestantId': '3czravw89omgc9o4s0w3l1bg5',
#    'periodId': 2,
#    'timeMin': 89,
#    'timeMinSec': '88:02',
#    'lastUpdated': '2025-08-07T15:18:57Z',
#    'timestamp': '2025-05-25T20:48:38Z',
#    'playerOnId': 'v7isqpxiursyjhj5rmhyhjv9',
#    'playerOnName': 'Íñigo Lekue',
#    'playerOffId': 'e9wu8g45hq2c1vp07jktx0set',
#    'playerOffName': 'De Marcos',
#    'subReason': 'Tactical'},
#   {'contestantId': 'agh9ifb2mw3ivjusgedj7c3fe',
#    'periodId': 2,
#    'timeMin': 89,
#    'timeMinSec': '88:10',
#    'lastUpdated': '2025-05-25T20:49:14Z',
#    'timestamp': '2025-05-25T20:48:46Z',
#    'playerOnId': '9f0jk3wgmlnnmnqrdkh4gnpt6',
#    'playerOnName': 'Pau Víctor',
#    'playerOffId': 'afxjicw89683nlpms9yy5x51x',
#    'playerOffName': 'R. Lewandowski',
#    'subReason': 'Tactical'}],
#  'VAR': [{'contestantId': 'agh9ifb2mw3ivjusgedj7c3fe',
#    'periodId': 2,
#    'timeMin': 92,
#    'timeMinSec': '91:26',
#    'lastUpdated': '2025-09-16T09:22:19Z',
#    'timestamp': '2025-05-25T20:51:32Z',
#    'type': 'Penalty not awarded',
#    'decision': 'Cancelled',
#    'outcome': 'Penalty',
#    'playerId': '4gq1u1mqg0qzekh1u5djleeax',
#    'playerName': 'Dani Olmo',
#    'optaEventId': '2819160741'}],
#  'lineUp': [{'contestantId': '3czravw89omgc9o4s0w3l1bg5',
#    'formationUsed': '4231',
#    'player': [{'playerId': '4vlurpsi44g09g159t61u83bp',
#      'firstName': 'Unai',
#      'lastName': 'Simón Mendibil',
#      'shortFirstName': 'Unai',
#      'shortLastName': 'Simón',
#      'matchName': 'Unai Simón',
#      'shirtNumber': 1,
#      'position': 'Goalkeeper',
#      'positionSide': 'Centre',
#      'formationPlace': '1',
#      'stat': [{'type': 'minsPlayed', 'value': '90'},
#       {'type': 'totalClearance', 'value': '2'},
#       {'type': 'lostCorners', 'value': '1'},
#       {'type': 'goalsConceded', 'value': '3'},
#       {'type': 'penaltyFaced', 'value': '1'},
#       {'type': 'accuratePass', 'value': '10'},
#       {'type': 'penGoalsConceded', 'value': '1'},
#       {'type': 'saves', 'value': '1'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalPass', 'value': '20'},
#       {'type': 'goalKicks', 'value': '6'},
#       {'type': 'formationPlace', 'value': '1'}]},
#     {'playerId': '8hm6d6395johhjsoe8jz6dcyd',
#      'firstName': 'Yuri',
#      'lastName': 'Berchiche Izeta',
#      'shortFirstName': 'Yuri',
#      'shortLastName': 'Berchiche',
#      'matchName': 'Yuri',
#      'shirtNumber': 17,
#      'position': 'Defender',
#      'positionSide': 'Left',
#      'formationPlace': '3',
#      'stat': [{'type': 'goalsConceded', 'value': '3'},
#       {'type': 'totalThrows', 'value': '9'},
#       {'type': 'lostCorners', 'value': '2'},
#       {'type': 'fouls', 'value': '3'},
#       {'type': 'minsPlayed', 'value': '90'},
#       {'type': 'totalClearance', 'value': '3'},
#       {'type': 'accuratePass', 'value': '16'},
#       {'type': 'wonCorners', 'value': '1'},
#       {'type': 'yellowCard', 'value': '1'},
#       {'type': 'penGoalsConceded', 'value': '1'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'penaltyConceded', 'value': '1'},
#       {'type': 'totalPass', 'value': '19'},
#       {'type': 'formationPlace', 'value': '3'}]},
#     {'playerId': '5kd57453a90zahgdxwkghr816',
#      'firstName': 'Aitor',
#      'lastName': 'Paredes Casamichana',
#      'shortFirstName': 'Aitor',
#      'shortLastName': 'Paredes',
#      'matchName': 'Aitor Paredes',
#      'shirtNumber': 4,
#      'position': 'Defender',
#      'positionSide': 'Left/Centre',
#      'formationPlace': '6',
#      'stat': [{'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalPass', 'value': '19'},
#       {'type': 'wonTackle', 'value': '1'},
#       {'type': 'shotOffTarget', 'value': '1'},
#       {'type': 'penGoalsConceded', 'value': '1'},
#       {'type': 'totalTackle', 'value': '1'},
#       {'type': 'accuratePass', 'value': '13'},
#       {'type': 'totalScoringAtt', 'value': '1'},
#       {'type': 'goalsConceded', 'value': '3'},
#       {'type': 'lostCorners', 'value': '1'},
#       {'type': 'minsPlayed', 'value': '90'},
#       {'type': 'totalClearance', 'value': '5'},
#       {'type': 'formationPlace', 'value': '6'}]},
#     {'playerId': 'e8s9ssopq5nmp51zymvqp8jbp',
#      'firstName': 'Unai',
#      'lastName': 'Núñez Gestoso',
#      'shortFirstName': 'Unai',
#      'shortLastName': 'Núñez',
#      'matchName': 'Unai Núñez',
#      'shirtNumber': 14,
#      'position': 'Defender',
#      'positionSide': 'Centre/Right',
#      'formationPlace': '5',
#      'stat': [{'type': 'accuratePass', 'value': '12'},
#       {'type': 'totalTackle', 'value': '1'},
#       {'type': 'goalsConceded', 'value': '2'},
#       {'type': 'minsPlayed', 'value': '62'},
#       {'type': 'fouls', 'value': '1'},
#       {'type': 'totalClearance', 'value': '3'},
#       {'type': 'totalOffside', 'value': '1'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalPass', 'value': '14'},
#       {'type': 'totalSubOff', 'value': '1'},
#       {'type': 'wonTackle', 'value': '1'},
#       {'type': 'formationPlace', 'value': '5'}]},
#     {'playerId': 'e9wu8g45hq2c1vp07jktx0set',
#      'firstName': 'Óscar',
#      'lastName': 'de Marcos Arana',
#      'shortFirstName': 'Óscar',
#      'shortLastName': 'De Marcos',
#      'matchName': 'De Marcos',
#      'shirtNumber': 18,
#      'position': 'Defender',
#      'positionSide': 'Right',
#      'formationPlace': '2',
#      'captain': 'yes',
#      'stat': [{'type': 'accuratePass', 'value': '18'},
#       {'type': 'goalsConceded', 'value': '2'},
#       {'type': 'minsPlayed', 'value': '89'},
#       {'type': 'fouls', 'value': '1'},
#       {'type': 'totalClearance', 'value': '3'},
#       {'type': 'totalThrows', 'value': '2'},
#       {'type': 'lostCorners', 'value': '1'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalPass', 'value': '23'},
#       {'type': 'totalSubOff', 'value': '1'},
#       {'type': 'formationPlace', 'value': '2'}]},
#     {'playerId': 'ck7lu09geq8mi6vkf2llyi5ii',
#      'firstName': 'Mikel',
#      'lastName': 'Jauregizar Alboniga',
#      'shortFirstName': 'Mikel',
#      'shortLastName': 'Jauregizar',
#      'matchName': 'Mikel Jauregizar',
#      'shirtNumber': 23,
#      'position': 'Defensive Midfielder',
#      'positionSide': 'Left/Centre',
#      'formationPlace': '4',
#      'stat': [{'type': 'penGoalsConceded', 'value': '1'},
#       {'type': 'wonTackle', 'value': '1'},
#       {'type': 'totalPass', 'value': '19'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'minsPlayed', 'value': '90'},
#       {'type': 'fouls', 'value': '4'},
#       {'type': 'wasFouled', 'value': '2'},
#       {'type': 'goalsConceded', 'value': '3'},
#       {'type': 'totalScoringAtt', 'value': '1'},
#       {'type': 'totalTackle', 'value': '2'},
#       {'type': 'accuratePass', 'value': '18'},
#       {'type': 'ontargetScoringAtt', 'value': '1'},
#       {'type': 'formationPlace', 'value': '4'}]},
#     {'playerId': '7ubtan6a51o79w469zawrqqqd',
#      'firstName': 'Íñigo',
#      'lastName': 'Ruíz de Galarreta Etxeberria',
#      'shortFirstName': 'Íñigo',
#      'shortLastName': 'Ruíz de Galarreta',
#      'matchName': 'Íñigo Ruíz de Galarreta',
#      'shirtNumber': 16,
#      'position': 'Defensive Midfielder',
#      'positionSide': 'Centre/Right',
#      'formationPlace': '8',
#      'stat': [{'type': 'accuratePass', 'value': '14'},
#       {'type': 'totalTackle', 'value': '1'},
#       {'type': 'totalScoringAtt', 'value': '1'},
#       {'type': 'goalsConceded', 'value': '2'},
#       {'type': 'wasFouled', 'value': '1'},
#       {'type': 'totalClearance', 'value': '1'},
#       {'type': 'fouls', 'value': '4'},
#       {'type': 'minsPlayed', 'value': '62'},
#       {'type': 'lostCorners', 'value': '1'},
#       {'type': 'totalOffside', 'value': '1'},
#       {'type': 'totalPass', 'value': '16'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalSubOff', 'value': '1'},
#       {'type': 'wonTackle', 'value': '1'},
#       {'type': 'shotOffTarget', 'value': '1'},
#       {'type': 'formationPlace', 'value': '8'}]},
#     {'playerId': '66jotyvbhtz5cjvhbby6luelm',
#      'firstName': 'Nicholas',
#      'lastName': 'Williams Arthuer',
#      'shortFirstName': 'Nico',
#      'shortLastName': 'Williams',
#      'knownName': 'Nico Williams',
#      'matchName': 'Nico Williams',
#      'shirtNumber': 10,
#      'position': 'Attacking Midfielder',
#      'positionSide': 'Left',
#      'formationPlace': '11',
#      'stat': [{'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalPass', 'value': '17'},
#       {'type': 'totalSubOff', 'value': '1'},
#       {'type': 'wonTackle', 'value': '1'},
#       {'type': 'shotOffTarget', 'value': '2'},
#       {'type': 'accuratePass', 'value': '11'},
#       {'type': 'totalTackle', 'value': '1'},
#       {'type': 'totalScoringAtt', 'value': '2'},
#       {'type': 'goalsConceded', 'value': '2'},
#       {'type': 'fouls', 'value': '1'},
#       {'type': 'minsPlayed', 'value': '80'},
#       {'type': 'formationPlace', 'value': '11'}]},
#     {'playerId': 'b2rqgjegzeyq6wy6qu63zz2fo',
#      'firstName': 'Unai',
#      'lastName': 'Gómez Etxebarria',
#      'shortFirstName': 'Unai',
#      'shortLastName': 'Gómez',
#      'matchName': 'Unai Gómez',
#      'shirtNumber': 20,
#      'position': 'Attacking Midfielder',
#      'positionSide': 'Centre',
#      'formationPlace': '10',
#      'stat': [{'type': 'totalPass', 'value': '13'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalSubOff', 'value': '1'},
#       {'type': 'shotOffTarget', 'value': '1'},
#       {'type': 'accuratePass', 'value': '12'},
#       {'type': 'totalScoringAtt', 'value': '1'},
#       {'type': 'goalsConceded', 'value': '2'},
#       {'type': 'totalClearance', 'value': '1'},
#       {'type': 'fouls', 'value': '1'},
#       {'type': 'minsPlayed', 'value': '62'},
#       {'type': 'formationPlace', 'value': '10'}]},
#     {'playerId': 'do5tibysnhbnbw18nwdo39kut',
#      'firstName': 'Alejandro',
#      'lastName': 'Berenguer Remiro',
#      'shortFirstName': 'Alex',
#      'shortLastName': 'Berenguer',
#      'matchName': 'Alex Berenguer',
#      'shirtNumber': 7,
#      'position': 'Attacking Midfielder',
#      'positionSide': 'Right',
#      'formationPlace': '7',
#      'stat': [{'type': 'totalOffside', 'value': '1'},
#       {'type': 'totalPass', 'value': '19'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'wonTackle', 'value': '2'},
#       {'type': 'penGoalsConceded', 'value': '1'},
#       {'type': 'accuratePass', 'value': '11'},
#       {'type': 'totalTackle', 'value': '2'},
#       {'type': 'cornerTaken', 'value': '2'},
#       {'type': 'goalsConceded', 'value': '3'},
#       {'type': 'wasFouled', 'value': '1'},
#       {'type': 'minsPlayed', 'value': '90'},
#       {'type': 'formationPlace', 'value': '7'}]},
#     {'playerId': 'by8xbw0rb239l1x4b0t33tpn8',
#      'firstName': 'Maroan',
#      'lastName': 'Sannadi Harrouch',
#      'shortFirstName': 'Maroan',
#      'shortLastName': 'Sannadi',
#      'matchName': 'M. Sannadi',
#      'shirtNumber': 21,
#      'position': 'Striker',
#      'positionSide': 'Centre',
#      'formationPlace': '9',
#      'stat': [{'type': 'penGoalsConceded', 'value': '1'},
#       {'type': 'shotOffTarget', 'value': '2'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalPass', 'value': '16'},
#       {'type': 'totalOffside', 'value': '2'},
#       {'type': 'fouls', 'value': '2'},
#       {'type': 'minsPlayed', 'value': '90'},
#       {'type': 'totalClearance', 'value': '1'},
#       {'type': 'goalsConceded', 'value': '3'},
#       {'type': 'wasFouled', 'value': '5'},
#       {'type': 'totalScoringAtt', 'value': '2'},
#       {'type': 'accuratePass', 'value': '13'},
#       {'type': 'formationPlace', 'value': '9'}]},
#     {'playerId': '1tctbwsidibct7wphjgv8mdm2',
#      'firstName': 'Julen',
#      'lastName': 'Agirrezabala Astúlez',
#      'shortFirstName': 'Julen',
#      'shortLastName': 'Agirrezabala',
#      'matchName': 'Julen Agirrezabala',
#      'shirtNumber': 13,
#      'position': 'Substitute',
#      'subPosition': 'Goalkeeper',
#      'stat': [{'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': '5ayo0fp6wod7cqg71e38zdz4k',
#      'firstName': 'Adama',
#      'lastName': 'Boiro Boiro',
#      'shortFirstName': 'Adama',
#      'shortLastName': 'Boiro',
#      'matchName': 'Adama Boiro',
#      'shirtNumber': 32,
#      'position': 'Substitute',
#      'subPosition': 'Defender',
#      'stat': [{'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': 'ccokndnkkyllbp5vb8nwnhdlg',
#      'firstName': 'Peio',
#      'lastName': 'Canales Urtasun',
#      'shortFirstName': 'Peio',
#      'shortLastName': 'Canales',
#      'matchName': 'Peio Canales',
#      'shirtNumber': 28,
#      'position': 'Substitute',
#      'subPosition': 'Midfielder',
#      'stat': [{'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': '23d0t7gqlra3jkskn18bh752i',
#      'firstName': 'Álvaro',
#      'lastName': 'Djaló Dias-Fernandes',
#      'shortFirstName': 'Álvaro',
#      'shortLastName': 'Djaló Dias-Fernandes',
#      'knownName': 'Álvaro Djaló',
#      'matchName': 'Álvaro Djaló',
#      'shirtNumber': 11,
#      'position': 'Substitute',
#      'subPosition': 'Attacker',
#      'stat': [{'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': 'b91n9sdabth8oocdawayybdud',
#      'firstName': 'Andoni',
#      'lastName': 'Gorosabel Espinosa',
#      'shortFirstName': 'Andoni',
#      'shortLastName': 'Gorosabel',
#      'matchName': 'Andoni Gorosabel',
#      'shirtNumber': 2,
#      'position': 'Substitute',
#      'subPosition': 'Defender',
#      'stat': [{'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': '3tzvbdszdrj1tayik9igbve8l',
#      'firstName': 'Gorka',
#      'lastName': 'Guruzeta Rodríguez',
#      'shortFirstName': 'Gorka',
#      'shortLastName': 'Guruzeta',
#      'matchName': 'Gorka Guruzeta',
#      'shirtNumber': 12,
#      'position': 'Substitute',
#      'subPosition': 'Attacker',
#      'stat': [{'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': 'v7isqpxiursyjhj5rmhyhjv9',
#      'firstName': 'Íñigo',
#      'lastName': 'Lekue Martínez',
#      'shortFirstName': 'Íñigo',
#      'shortLastName': 'Lekue',
#      'matchName': 'Íñigo Lekue',
#      'shirtNumber': 15,
#      'position': 'Substitute',
#      'subPosition': 'Defender',
#      'stat': [{'type': 'accuratePass', 'value': '1'},
#       {'type': 'minsPlayed', 'value': '1'},
#       {'type': 'totalSubOn', 'value': '1'},
#       {'type': 'goalsConceded', 'value': '1'},
#       {'type': 'totalPass', 'value': '1'},
#       {'type': 'penGoalsConceded', 'value': '1'},
#       {'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': '352ywlfcjt329s7etjn4rkui2',
#      'firstName': 'Beñat',
#      'lastName': 'Prados Díaz',
#      'shortFirstName': 'Beñat',
#      'shortLastName': 'Prados',
#      'matchName': 'Beñat Prados',
#      'shirtNumber': 24,
#      'position': 'Substitute',
#      'subPosition': 'Midfielder',
#      'stat': [{'type': 'fouls', 'value': '3'},
#       {'type': 'minsPlayed', 'value': '28'},
#       {'type': 'totalSubOn', 'value': '1'},
#       {'type': 'goalsConceded', 'value': '1'},
#       {'type': 'wonCorners', 'value': '1'},
#       {'type': 'totalScoringAtt', 'value': '1'},
#       {'type': 'accuratePass', 'value': '7'},
#       {'type': 'totalTackle', 'value': '3'},
#       {'type': 'penGoalsConceded', 'value': '1'},
#       {'type': 'shotOffTarget', 'value': '1'},
#       {'type': 'wonTackle', 'value': '2'},
#       {'type': 'totalPass', 'value': '7'},
#       {'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': 'dfcbvsb7o18lavmonbp5ucwoa',
#      'firstName': 'Oihan',
#      'lastName': 'Sancet Tirapu',
#      'shortFirstName': 'Oihan',
#      'shortLastName': 'Sancet',
#      'matchName': 'Oihan Sancet',
#      'shirtNumber': 8,
#      'position': 'Substitute',
#      'subPosition': 'Midfielder',
#      'stat': [{'type': 'goalsConceded', 'value': '1'},
#       {'type': 'fouls', 'value': '1'},
#       {'type': 'minsPlayed', 'value': '28'},
#       {'type': 'totalSubOn', 'value': '1'},
#       {'type': 'accuratePass', 'value': '6'},
#       {'type': 'penGoalsConceded', 'value': '1'},
#       {'type': 'totalPass', 'value': '7'},
#       {'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': '83n1qv6ypl625aolzjeqifv11',
#      'firstName': 'Mikel',
#      'lastName': 'Vesga Arruti',
#      'shortFirstName': 'Mikel',
#      'shortLastName': 'Vesga',
#      'matchName': 'Mikel Vesga',
#      'shirtNumber': 6,
#      'position': 'Substitute',
#      'subPosition': 'Midfielder',
#      'stat': [{'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': '9d5h5wxf44qu4fw3jk2pgis16',
#      'firstName': 'Daniel',
#      'lastName': 'Vivian Moreno',
#      'shortFirstName': 'Dani',
#      'shortLastName': 'Vivian',
#      'matchName': 'Dani Vivian',
#      'shirtNumber': 3,
#      'position': 'Substitute',
#      'subPosition': 'Defender',
#      'stat': [{'type': 'penGoalsConceded', 'value': '1'},
#       {'type': 'totalPass', 'value': '5'},
#       {'type': 'goalsConceded', 'value': '1'},
#       {'type': 'totalSubOn', 'value': '1'},
#       {'type': 'minsPlayed', 'value': '28'},
#       {'type': 'accuratePass', 'value': '5'},
#       {'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': 'ddvvwqxpsqqboupi3gx1ijhed',
#      'firstName': 'Iñaki',
#      'lastName': 'Williams Arthuer',
#      'shortFirstName': 'Iñaki',
#      'shortLastName': 'Williams',
#      'knownName': 'Iñaki Williams',
#      'matchName': 'I. Williams',
#      'shirtNumber': 9,
#      'position': 'Substitute',
#      'subPosition': 'Attacker',
#      'stat': [{'type': 'totalOffside', 'value': '1'},
#       {'type': 'totalPass', 'value': '1'},
#       {'type': 'penGoalsConceded', 'value': '1'},
#       {'type': 'goalsConceded', 'value': '1'},
#       {'type': 'totalSubOn', 'value': '1'},
#       {'type': 'minsPlayed', 'value': '10'},
#       {'type': 'formationPlace', 'value': '0'}]}],
#    'teamOfficial': [{'id': 'dbdq6fyl44p43la2s5q9suehh',
#      'firstName': 'Ernesto',
#      'lastName': 'Valverde Tejedor',
#      'shortFirstName': 'Ernesto',
#      'shortLastName': 'Valverde',
#      'type': 'manager'}],
#    'stat': [{'fh': '7', 'sh': '2', 'type': 'fkFoulWon', 'value': '9'},
#     {'fh': '2', 'sh': '1', 'type': 'goalsConceded', 'value': '3'},
#     {'fh': '0', 'sh': '1', 'type': 'totalYellowCard', 'value': '1'},
#     {'fh': '14', 'sh': '5', 'type': 'totalClearance', 'value': '19'},
#     {'fh': '4', 'sh': '2', 'type': 'lostCorners', 'value': '6'},
#     {'fh': '8', 'sh': '3', 'type': 'totalThrows', 'value': '11'},
#     {'fh': '92', 'sh': '75', 'type': 'accuratePass', 'value': '167'},
#     {'fh': '0', 'sh': '1', 'type': 'ontargetScoringAtt', 'value': '1'},
#     {'fh': '4', 'sh': '7', 'type': 'totalTackle', 'value': '11'},
#     {'fh': '0', 'sh': '2', 'type': 'cornerTaken', 'value': '2'},
#     {'fh': '0', 'sh': '2', 'type': 'wonCorners', 'value': '2'},
#     {'fh': '0', 'sh': '1', 'type': 'penaltyFaced', 'value': '1'},
#     {'fh': '4', 'sh': '5', 'type': 'totalScoringAtt', 'value': '9'},
#     {'fh': '0', 'sh': '1', 'type': 'saves', 'value': '1'},
#     {'fh': '4', 'sh': '5', 'type': 'wonTackle', 'value': '9'},
#     {'fh': '0', 'sh': '1', 'type': 'penGoalsConceded', 'value': '1'},
#     {'fh': '25.6',
#      'sh': '22.5',
#      'type': 'possessionPercentage',
#      'value': '24'},
#     {'fh': '4', 'sh': '4', 'type': 'shotOffTarget', 'value': '8'},
#     {'fh': '0', 'sh': '5', 'type': 'subsMade', 'value': '5'},
#     {'fh': '4', 'sh': '2', 'type': 'totalOffside', 'value': '6'},
#     {'fh': '10', 'sh': '11', 'type': 'fkFoulLost', 'value': '21'},
#     {'fh': '113', 'sh': '103', 'type': 'totalPass', 'value': '216'},
#     {'fh': '0', 'sh': '1', 'type': 'penaltyConceded', 'value': '1'},
#     {'fh': '1', 'sh': '5', 'type': 'goalKicks', 'value': '6'},
#     {'type': 'formationUsed', 'value': '4231'}],
#    'kit': {'id': '12043',
#     'colour1': '#FF0000',
#     'colour2': '#FFFFFF',
#     'type': 'home'}},
#   {'contestantId': 'agh9ifb2mw3ivjusgedj7c3fe',
#    'formationUsed': '4231',
#    'player': [{'playerId': '4mxx1oxkiexm0ha34utcmb17t',
#      'firstName': 'Ignacio',
#      'lastName': 'Peña Sotorres',
#      'shortFirstName': 'Iñaki',
#      'shortLastName': 'Peña',
#      'matchName': 'Iñaki Peña',
#      'shirtNumber': 13,
#      'position': 'Goalkeeper',
#      'positionSide': 'Centre',
#      'formationPlace': '1',
#      'stat': [{'type': 'minsPlayed', 'value': '90'},
#       {'type': 'totalClearance', 'value': '1'},
#       {'type': 'cleanSheet', 'value': '1'},
#       {'type': 'accuratePass', 'value': '35'},
#       {'type': 'saves', 'value': '2'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalPass', 'value': '36'},
#       {'type': 'goalKicks', 'value': '7'},
#       {'type': 'formationPlace', 'value': '1'}]},
#     {'playerId': 'bzgh5psb1janz9y3btpswngbu',
#      'firstName': 'Alejandro',
#      'lastName': 'Balde Martínez',
#      'shortFirstName': 'Alejandro',
#      'shortLastName': 'Balde',
#      'matchName': 'Alejandro Balde',
#      'shirtNumber': 3,
#      'position': 'Defender',
#      'positionSide': 'Left',
#      'formationPlace': '3',
#      'stat': [{'type': 'totalSubOff', 'value': '1'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalPass', 'value': '64'},
#       {'type': 'totalThrows', 'value': '3'},
#       {'type': 'fouls', 'value': '2'},
#       {'type': 'minsPlayed', 'value': '81'},
#       {'type': 'wasFouled', 'value': '2'},
#       {'type': 'accuratePass', 'value': '60'},
#       {'type': 'formationPlace', 'value': '3'}]},
#     {'playerId': 'bkwxem45cf48k14euwqe7rs44',
#      'firstName': 'Pau',
#      'lastName': 'Cubarsí Paredes',
#      'shortFirstName': 'Pau',
#      'shortLastName': 'Cubarsí',
#      'matchName': 'Pau Cubarsí',
#      'shirtNumber': 2,
#      'position': 'Defender',
#      'positionSide': 'Left/Centre',
#      'formationPlace': '6',
#      'stat': [{'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalPass', 'value': '46'},
#       {'type': 'totalTackle', 'value': '1'},
#       {'type': 'accuratePass', 'value': '45'},
#       {'type': 'cleanSheet', 'value': '1'},
#       {'type': 'totalThrows', 'value': '1'},
#       {'type': 'fouls', 'value': '4'},
#       {'type': 'minsPlayed', 'value': '90'},
#       {'type': 'totalClearance', 'value': '4'},
#       {'type': 'wasFouled', 'value': '1'},
#       {'type': 'formationPlace', 'value': '6'}]},
#     {'playerId': 'awsod0zmnrukk21d4882ji7e1',
#      'firstName': 'Ronald Federico',
#      'lastName': 'Araujo da Silva',
#      'shortFirstName': 'Ronald',
#      'shortLastName': 'Araujo',
#      'matchName': 'R. Araujo',
#      'shirtNumber': 4,
#      'position': 'Defender',
#      'positionSide': 'Centre/Right',
#      'formationPlace': '5',
#      'captain': 'yes',
#      'stat': [{'type': 'totalSubOff', 'value': '1'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalPass', 'value': '82'},
#       {'type': 'minsPlayed', 'value': '64'},
#       {'type': 'totalClearance', 'value': '4'},
#       {'type': 'wasFouled', 'value': '1'},
#       {'type': 'wonCorners', 'value': '1'},
#       {'type': 'accuratePass', 'value': '80'},
#       {'type': 'formationPlace', 'value': '5'}]},
#     {'playerId': '4ggz7e009bq3yltc9o6mifbah',
#      'firstName': 'Eric',
#      'lastName': 'García Martret',
#      'shortFirstName': 'Eric',
#      'shortLastName': 'García',
#      'knownName': 'Eric García',
#      'matchName': 'Eric García',
#      'shirtNumber': 24,
#      'position': 'Defender',
#      'positionSide': 'Right',
#      'formationPlace': '2',
#      'stat': [{'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalPass', 'value': '79'},
#       {'type': 'wonTackle', 'value': '2'},
#       {'type': 'totalTackle', 'value': '5'},
#       {'type': 'accuratePass', 'value': '71'},
#       {'type': 'cleanSheet', 'value': '1'},
#       {'type': 'wonCorners', 'value': '1'},
#       {'type': 'totalThrows', 'value': '10'},
#       {'type': 'lostCorners', 'value': '1'},
#       {'type': 'minsPlayed', 'value': '90'},
#       {'type': 'totalClearance', 'value': '1'},
#       {'type': 'formationPlace', 'value': '2'}]},
#     {'playerId': '4ftlhtels58lyzfluwofzwxuy',
#      'firstName': 'Pedro',
#      'lastName': 'González López',
#      'shortFirstName': 'Pedro',
#      'shortLastName': 'González López',
#      'knownName': 'Pedri',
#      'matchName': 'Pedri',
#      'shirtNumber': 8,
#      'position': 'Defensive Midfielder',
#      'positionSide': 'Left/Centre',
#      'formationPlace': '4',
#      'stat': [{'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalPass', 'value': '123'},
#       {'type': 'totalSubOff', 'value': '1'},
#       {'type': 'wonTackle', 'value': '2'},
#       {'type': 'accuratePass', 'value': '115'},
#       {'type': 'totalTackle', 'value': '2'},
#       {'type': 'minsPlayed', 'value': '81'},
#       {'type': 'wasFouled', 'value': '2'},
#       {'type': 'formationPlace', 'value': '4'}]},
#     {'playerId': 'eb3ci3a120om80v80mobsus8a',
#      'firstName': 'Pablo',
#      'lastName': 'Páez Gavira',
#      'shortFirstName': 'Pablo',
#      'shortLastName': 'Páez Gavira',
#      'knownName': 'Gavi',
#      'matchName': 'Gavi',
#      'shirtNumber': 6,
#      'position': 'Defensive Midfielder',
#      'positionSide': 'Centre/Right',
#      'formationPlace': '8',
#      'stat': [{'type': 'wonTackle', 'value': '3'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalPass', 'value': '98'},
#       {'type': 'wasFouled', 'value': '5'},
#       {'type': 'minsPlayed', 'value': '90'},
#       {'type': 'lostCorners', 'value': '1'},
#       {'type': 'cleanSheet', 'value': '1'},
#       {'type': 'accuratePass', 'value': '95'},
#       {'type': 'totalTackle', 'value': '8'},
#       {'type': 'formationPlace', 'value': '8'}]},
#     {'playerId': '2wl6h1rlrfnn2mr65vuo3t815',
#      'firstName': 'Raphael',
#      'lastName': 'Dias Belloli',
#      'shortFirstName': 'Raphael',
#      'shortLastName': 'Dias Belloli',
#      'knownName': 'Raphinha',
#      'matchName': 'Raphinha',
#      'shirtNumber': 11,
#      'position': 'Attacking Midfielder',
#      'positionSide': 'Left',
#      'formationPlace': '11',
#      'stat': [{'type': 'shotOffTarget', 'value': '1'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalPass', 'value': '28'},
#       {'type': 'totalSubOff', 'value': '1'},
#       {'type': 'minsPlayed', 'value': '64'},
#       {'type': 'totalClearance', 'value': '1'},
#       {'type': 'accuratePass', 'value': '23'},
#       {'type': 'cornerTaken', 'value': '2'},
#       {'type': 'totalScoringAtt', 'value': '1'},
#       {'type': 'formationPlace', 'value': '11'}]},
#     {'playerId': 'cjll1xrw3xulnl23c9tlf6rys',
#      'firstName': 'Fermín',
#      'lastName': 'López Marín',
#      'shortFirstName': 'Fermín',
#      'shortLastName': 'López',
#      'matchName': 'Fermín López',
#      'shirtNumber': 16,
#      'position': 'Attacking Midfielder',
#      'positionSide': 'Centre',
#      'formationPlace': '10',
#      'stat': [{'type': 'shotOffTarget', 'value': '1'},
#       {'type': 'wonTackle', 'value': '1'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalPass', 'value': '51'},
#       {'type': 'goalAssist', 'value': '1'},
#       {'type': 'fouls', 'value': '3'},
#       {'type': 'minsPlayed', 'value': '90'},
#       {'type': 'wasFouled', 'value': '4'},
#       {'type': 'totalScoringAtt', 'value': '1'},
#       {'type': 'accuratePass', 'value': '42'},
#       {'type': 'cleanSheet', 'value': '1'},
#       {'type': 'cornerTaken', 'value': '3'},
#       {'type': 'totalTackle', 'value': '1'},
#       {'type': 'formationPlace', 'value': '10'}]},
#     {'playerId': 'abr79wsl0folgkyvl821ggs2c',
#      'firstName': 'Lamine Yamal',
#      'lastName': 'Nasraoui Ebana',
#      'shortFirstName': 'Lamine Yamal',
#      'shortLastName': 'Nasraoui Ebana',
#      'knownName': 'Lamine Yamal',
#      'matchName': 'Lamine Yamal',
#      'shirtNumber': 19,
#      'position': 'Attacking Midfielder',
#      'positionSide': 'Right',
#      'formationPlace': '7',
#      'stat': [{'type': 'totalPass', 'value': '47'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'totalOffside', 'value': '1'},
#       {'type': 'shotOffTarget', 'value': '2'},
#       {'type': 'totalScoringAtt', 'value': '4'},
#       {'type': 'wonCorners', 'value': '3'},
#       {'type': 'cleanSheet', 'value': '1'},
#       {'type': 'ontargetScoringAtt', 'value': '1'},
#       {'type': 'accuratePass', 'value': '37'},
#       {'type': 'totalThrows', 'value': '2'},
#       {'type': 'fouls', 'value': '1'},
#       {'type': 'minsPlayed', 'value': '90'},
#       {'type': 'blockedScoringAtt', 'value': '1'},
#       {'type': 'formationPlace', 'value': '7'}]},
#     {'playerId': 'afxjicw89683nlpms9yy5x51x',
#      'firstName': 'Robert',
#      'lastName': 'Lewandowski',
#      'shortFirstName': 'Robert',
#      'shortLastName': 'Lewandowski',
#      'matchName': 'R. Lewandowski',
#      'shirtNumber': 9,
#      'position': 'Striker',
#      'positionSide': 'Centre',
#      'formationPlace': '9',
#      'stat': [{'type': 'totalScoringAtt', 'value': '5'},
#       {'type': 'wonCorners', 'value': '1'},
#       {'type': 'accuratePass', 'value': '7'},
#       {'type': 'ontargetScoringAtt', 'value': '2'},
#       {'type': 'minsPlayed', 'value': '89'},
#       {'type': 'wasFouled', 'value': '3'},
#       {'type': 'blockedScoringAtt', 'value': '2'},
#       {'type': 'totalSubOff', 'value': '1'},
#       {'type': 'totalPass', 'value': '8'},
#       {'type': 'gameStarted', 'value': '1'},
#       {'type': 'shotOffTarget', 'value': '1'},
#       {'type': 'goals', 'value': '2'},
#       {'type': 'formationPlace', 'value': '9'}]},
#     {'playerId': '1av9mmv19jwvc4xdr0p9owyxh',
#      'firstName': 'Andreas',
#      'lastName': 'Bødtker Christensen',
#      'shortFirstName': 'Andreas',
#      'shortLastName': 'Christensen',
#      'matchName': 'A. Christensen',
#      'shirtNumber': 15,
#      'position': 'Substitute',
#      'subPosition': 'Defender',
#      'stat': [{'type': 'minsPlayed', 'value': '26'},
#       {'type': 'totalClearance', 'value': '1'},
#       {'type': 'totalSubOn', 'value': '1'},
#       {'type': 'accuratePass', 'value': '29'},
#       {'type': 'totalScoringAtt', 'value': '1'},
#       {'type': 'shotOffTarget', 'value': '1'},
#       {'type': 'totalPass', 'value': '31'},
#       {'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': '3hht0os2uzu234yq550i3fbe2',
#      'firstName': 'Marc',
#      'lastName': 'Casadó Torras',
#      'shortFirstName': 'Marc',
#      'shortLastName': 'Casadó',
#      'matchName': 'Marc Casadó',
#      'shirtNumber': 17,
#      'position': 'Substitute',
#      'subPosition': 'Midfielder',
#      'stat': [{'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': '308krssmz6irpfntht1ka78tm',
#      'firstName': 'Anssumane',
#      'lastName': 'Fati Vieira',
#      'shortFirstName': 'Ansu',
#      'shortLastName': 'Fati',
#      'matchName': 'Ansu Fati',
#      'shirtNumber': 10,
#      'position': 'Substitute',
#      'subPosition': 'Attacker',
#      'stat': [{'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': '8xjdsfk5u7wph4o7h1w45dses',
#      'firstName': 'Héctor',
#      'lastName': 'Fort García',
#      'shortFirstName': 'Héctor',
#      'shortLastName': 'Fort',
#      'matchName': 'Héctor Fort',
#      'shirtNumber': 32,
#      'position': 'Substitute',
#      'subPosition': 'Defender',
#      'stat': [{'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': '6l1y87tlepsvr83d8y2qifeqy',
#      'firstName': 'Gerard',
#      'lastName': 'Martín Langreo',
#      'shortFirstName': 'Gerard',
#      'shortLastName': 'Martín',
#      'matchName': 'Gerard Martín',
#      'shirtNumber': 35,
#      'position': 'Substitute',
#      'subPosition': 'Defender',
#      'stat': [{'type': 'totalSubOn', 'value': '1'},
#       {'type': 'minsPlayed', 'value': '9'},
#       {'type': 'accuratePass', 'value': '2'},
#       {'type': 'totalPass', 'value': '3'},
#       {'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': 'cd5napttmwk5o9gxw3cbb4ted',
#      'firstName': 'Iñigo',
#      'lastName': 'Martínez Berridi',
#      'shortFirstName': 'Iñigo',
#      'shortLastName': 'Martínez',
#      'matchName': 'Iñigo Martínez',
#      'shirtNumber': 5,
#      'position': 'Substitute',
#      'subPosition': 'Defender',
#      'stat': [{'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': '4gq1u1mqg0qzekh1u5djleeax',
#      'firstName': 'Daniel',
#      'lastName': 'Olmo Carvajal',
#      'shortFirstName': 'Dani',
#      'shortLastName': 'Olmo',
#      'matchName': 'Dani Olmo',
#      'shirtNumber': 20,
#      'position': 'Substitute',
#      'subPosition': 'Midfielder',
#      'stat': [{'type': 'penaltyWon', 'value': '1'},
#       {'type': 'wasFouled', 'value': '3'},
#       {'type': 'totalClearance', 'value': '1'},
#       {'type': 'minsPlayed', 'value': '26'},
#       {'type': 'totalSubOn', 'value': '1'},
#       {'type': 'ontargetScoringAtt', 'value': '1'},
#       {'type': 'accuratePass', 'value': '14'},
#       {'type': 'cornerTaken', 'value': '1'},
#       {'type': 'totalScoringAtt', 'value': '1'},
#       {'type': 'goals', 'value': '1'},
#       {'type': 'totalPass', 'value': '16'},
#       {'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': '6ofu6yc2qwp5ii9cerdq1tk9h',
#      'firstName': 'Wojciech Tomasz',
#      'lastName': 'Szczęsny',
#      'shortFirstName': 'Wojciech',
#      'shortLastName': 'Szczesny',
#      'matchName': 'W. Szczęsny',
#      'shirtNumber': 25,
#      'position': 'Substitute',
#      'subPosition': 'Goalkeeper',
#      'stat': [{'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': '5kodjbsarkql4vhs126p2vhwq',
#      'firstName': 'Pablo',
#      'lastName': 'Torre Carral',
#      'shortFirstName': 'Pablo',
#      'shortLastName': 'Torre',
#      'matchName': 'Pablo Torre',
#      'shirtNumber': 14,
#      'position': 'Substitute',
#      'subPosition': 'Midfielder',
#      'stat': [{'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': '9f0jk3wgmlnnmnqrdkh4gnpt6',
#      'firstName': 'Pau',
#      'lastName': 'Víctor Delgado',
#      'shortFirstName': 'Pau',
#      'shortLastName': 'Víctor',
#      'matchName': 'Pau Víctor',
#      'shirtNumber': 18,
#      'position': 'Substitute',
#      'subPosition': 'Attacker',
#      'stat': [{'type': 'minsPlayed', 'value': '1'},
#       {'type': 'totalSubOn', 'value': '1'},
#       {'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': 'ezviixcyaaj162saxs2yl27s9',
#      'firstName': 'Frenkie',
#      'lastName': 'de Jong',
#      'shortFirstName': 'Frenkie',
#      'shortLastName': 'de Jong',
#      'matchName': 'F. de Jong',
#      'shirtNumber': 21,
#      'position': 'Substitute',
#      'subPosition': 'Midfielder',
#      'stat': [{'type': 'totalSubOn', 'value': '1'},
#       {'type': 'minsPlayed', 'value': '9'},
#       {'type': 'totalClearance', 'value': '1'},
#       {'type': 'accuratePass', 'value': '8'},
#       {'type': 'totalPass', 'value': '8'},
#       {'type': 'formationPlace', 'value': '0'}]},
#     {'playerId': '2e55g4q93y382cg7h0yk5rtud',
#      'firstName': 'Marc-André',
#      'lastName': 'ter Stegen',
#      'shortFirstName': 'Marc-André',
#      'shortLastName': 'ter Stegen',
#      'matchName': 'M. ter Stegen',
#      'shirtNumber': 1,
#      'position': 'Substitute',
#      'subPosition': 'Goalkeeper',
#      'stat': [{'type': 'formationPlace', 'value': '0'}]}],
#    'teamOfficial': [{'id': 'ebm098y98ctdw0zs1l1kvnt62',
#      'firstName': 'Hans-Dieter',
#      'lastName': 'Flick',
#      'shortFirstName': 'Hansi',
#      'shortLastName': 'Flick',
#      'type': 'manager'}],
#    'stat': [{'fh': '2', 'sh': '4', 'type': 'shotOffTarget', 'value': '6'},
#     {'fh': '74.4',
#      'sh': '77.5',
#      'type': 'possessionPercentage',
#      'value': '76'},
#     {'fh': '7', 'sh': '1', 'type': 'wonTackle', 'value': '8'},
#     {'fh': '2', 'sh': '1', 'type': 'goals', 'value': '3'},
#     {'fh': '0', 'sh': '2', 'type': 'saves', 'value': '2'},
#     {'fh': '5', 'sh': '2', 'type': 'goalKicks', 'value': '7'},
#     {'fh': '0', 'sh': '1', 'type': 'subsGoals', 'value': '1'},
#     {'fh': '341', 'sh': '379', 'type': 'totalPass', 'value': '720'},
#     {'fh': '7', 'sh': '3', 'type': 'fkFoulLost', 'value': '10'},
#     {'fh': '0', 'sh': '1', 'type': 'totalOffside', 'value': '1'},
#     {'fh': '1', 'sh': '0', 'type': 'goalAssist', 'value': '1'},
#     {'fh': '0', 'sh': '5', 'type': 'subsMade', 'value': '5'},
#     {'fh': '8', 'sh': '8', 'type': 'totalThrows', 'value': '16'},
#     {'fh': '0', 'sh': '2', 'type': 'lostCorners', 'value': '2'},
#     {'fh': '5', 'sh': '9', 'type': 'totalClearance', 'value': '14'},
#     {'fh': '10', 'sh': '11', 'type': 'fkFoulWon', 'value': '21'},
#     {'fh': '1', 'sh': '2', 'type': 'blockedScoringAtt', 'value': '3'},
#     {'fh': '0', 'sh': '1', 'type': 'penaltyWon', 'value': '1'},
#     {'fh': '5', 'sh': '8', 'type': 'totalScoringAtt', 'value': '13'},
#     {'fh': '4', 'sh': '2', 'type': 'wonCorners', 'value': '6'},
#     {'fh': '4', 'sh': '2', 'type': 'cornerTaken', 'value': '6'},
#     {'fh': '11', 'sh': '6', 'type': 'totalTackle', 'value': '17'},
#     {'type': 'cleanSheet', 'value': '1'},
#     {'fh': '313', 'sh': '350', 'type': 'accuratePass', 'value': '663'},
#     {'fh': '2', 'sh': '2', 'type': 'ontargetScoringAtt', 'value': '4'},
#     {'type': 'formationUsed', 'value': '4231'}],
#    'kit': {'id': '25288',
#     'colour1': '#33FF00',
#     'colour2': '#99FF99',
#     'type': 'third'}}],
#  'matchDetailsExtra': {'attendance': '50231',
#   'matchOfficial': [{'id': 'a43uvomm1kkc5xsp2juvqz74l',
#     'type': 'Main',
#     'firstName': 'Pablo',
#     'lastName': 'González Fuertes',
#     'shortFirstName': 'Pablo',
#     'shortLastName': 'González Fuertes'},
#    {'id': 'dd4chwkjkgvc5gb4vjksu89nt',
#     'type': 'Assistant referee 1',
#     'firstName': 'Israel',
#     'lastName': 'Bárcena Rodríguez',
#     'shortFirstName': 'Israel',
#     'shortLastName': 'Bárcena Rodríguez'},
#    {'id': '138ddyyr34cjzejso92snxvit',
#     'type': 'Assistant referee 2',
#     'firstName': 'Rubén',
#     'lastName': 'Porras Rico',
#     'shortFirstName': 'Rubén',
#     'shortLastName': 'Porras Rico'},
#    {'id': 'dupzf229b57kq7jnnwio63oid',
#     'type': 'Fourth official',
#     'firstName': 'Rubén',
#     'lastName': 'Ruipérez Marín',
#     'shortFirstName': 'Rubén',
#     'shortLastName': 'Ruiperez Marín'},
#    {'id': '37u09m3xbwx9v4p9ybc5xg2c5',
#     'type': 'Video Assistant Referee',
#     'firstName': 'Carlos',
#     'lastName': 'del Cerro Grande',
#     'shortFirstName': 'Carlos',
#     'shortLastName': 'del Cerro Grande'},
#    {'id': '2xvd99irgqs4pddbipiilf55h',
#     'type': 'Assistant VAR Official',
#     'firstName': 'Adrián',
#     'lastName': 'Díaz González',
#     'shortFirstName': 'Adrián',
#     'shortLastName': 'Díaz González'}]}}
