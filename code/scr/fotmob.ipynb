# %%
import requests
import pandas as pd
import numpy as np
import os
import json as jsonlib
import time

out_path = 'C:\\Users\\xrosinach\\Desktop\\TFM-Scouting-FC-Barcelona\\data\\fm'

# Obtenemos el CSV con competiciones
cdir = os.getcwd()
utils = os.path.join(os.path.abspath(os.path.join(cdir, '..', '..')), 'utils')
comps = pd.read_csv(os.path.join(utils, 'comps.csv'), sep=';')

# Convertir un URL a JSON
def url_to_json(url: str) -> dict:

    out = requests.get(url).json()
    time.sleep(3)                           # Para garantir seguridad

    return out

# %%
# Obtenemos un diccionario JSON con las temporadas disponibles en una liga
def league_available_seasons(league_code: int, out_path: str) -> dict:

    # Entorno de carpetas output
    out_league_path = os.path.join(out_path, str(league_code))
    os.makedirs(out_league_path, exist_ok=True)
    json_path = os.path.join(out_league_path, 'AvailableSeasons.json')

    # Si existe el fichero
    if os.path.exists(json_path):
        with open(json_path, "r", encoding="utf-8") as f:
            available_seasons_json = jsonlib.load(f)
        return available_seasons_json

    # Si no existe entramos en el proceso de scraping
    fotmob_url = f'https://www.fotmob.com/api/leagues?id={league_code}'

    # Leer JSON y obtener lista con temporadas disponibles
    available_seasons_json = url_to_json(url=fotmob_url)
    available_seasons = available_seasons_json.get('allAvailableSeasons', [])

    # Diccionario para añadir info
    seasons_dict = {}

    # Para cada temporada, obtenemos el link
    for s in available_seasons:

        # Obtenemos el link a partir de sus años
        if "/" in s:
            start, end = s.split("/")           # Separación por año
            key_candidate = start[-2:] + end[-2:]
        else:
            s = s[:4]                           # Sino, primer año
            key_candidate = f"{int(s) % 100:02d}{(int(s)+1) % 100:02d}"

        season_link = f"{fotmob_url}&season={s}"

        # Guardamos temporada en key y link
        seasons_dict[s] = {"key": key_candidate, "link": season_link}

    # Substituimos dentro del JSON original
    available_seasons_json["allAvailableSeasons"] = seasons_dict

    # Guardado en JSON
    with open(json_path, "w", encoding="utf-8") as f:
        jsonlib.dump(available_seasons_json, f)
    
    return available_seasons_json

# A partir de la clave de una temporada obtenemos el JSON con su información
def season_data(seasons_dict: dict, season_key: str, league_code: int, out_path: str) -> dict:

    # Entorno de carpetas output
    out_league_path = os.path.join(out_path, str(league_code))
    os.makedirs(out_league_path, exist_ok=True)
    json_path = os.path.join(out_league_path, f'Season{season_key}.json')

    # Si existe el fichero
    if os.path.exists(json_path):
        with open(json_path, "r", encoding="utf-8") as f:
            season_json = jsonlib.load(f)
        return season_json
    
    # Si no existe, comprovamos
    if season_key not in seasons_dict.keys():
        return {}
    else:
        season_link = seasons_dict[season_key]

    # Leemos el link y guardado en JSON
    season_json = url_to_json(season_link)
    with open(json_path, "w", encoding="utf-8") as f:
        jsonlib.dump(season_json, f)
    
    return season_json

# Obtención de los datos de un partido usando su ID
def match_data(matches_dict: dict, match_id: str, league_code: int, out_path: str) -> dict:

    # Entorno de carpetas output
    out_league_path = os.path.join(out_path, str(league_code), 'matches')
    os.makedirs(out_league_path, exist_ok=True)
    json_path = os.path.join(out_league_path, f'Match{match_id}.json')

    # Si existe el fichero
    if os.path.exists(json_path):
        with open(json_path, "r", encoding="utf-8") as f:
            match_json = jsonlib.load(f)
        return match_json
    
    # Comprovamos que el ID esta entre los partidos
    if match_id not in matches_dict.keys():
        return {}
    else:
        match_link = matches_dict[match_id]
        print(match_id, json_path)

    # Leemos el link y guardado en JSON
    match_json = url_to_json(url=match_link)
    with open(json_path, "w", encoding="utf-8") as f:
        jsonlib.dump(match_json, f)
    
    return match_json

# %%
for i, row in comps.iterrows():

    # Temporadas disponibles de nuestra liga seleccionada
    available_seasons_json = league_available_seasons(league_code=int(row['fm']), out_path=out_path)

    # Diccionario con las temporadas que tengo y su link
    available_seasons = available_seasons_json.get('allAvailableSeasons', {}).values()
    seasons_dict = {v['key']: v['link'] for v in available_seasons}

    # Fichero de temporada a partir de la key
    for season in seasons_dict.keys():
        season_json = season_data(seasons_dict=seasons_dict, season_key=str(season), league_code=int(row['fm']), out_path=out_path)

    # Partidos y diccionario con los IDs
    matches = season_json.get('fixtures', {}).get('allMatches', {})
    dict_matches_urls = {match['id']: f'https://www.fotmob.com/api/matchDetails?matchId={match['id']}'
                        for match in matches if match.get('status', {}).get('finished', False)}
    
    # Fichero de partido a partir del ID de partido
    # for match in dict_matches_urls.keys():
    #     match_json = match_data(matches_dict=dict_matches_urls, match_id=str(match), league_code=int(row['fm']), out_path=out_path)

    print(f'{row['tournament']} ({i+1}/{len(comps)})')
# Out:
# Liga Profesional (1/64)
# Bundesliga Austria (2/64)
# A-League (3/64)
# First Division A (4/64)
# Primera División (5/64)
# Serie A Brazil (6/64)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 12
#      10 # Fichero de temporada a partir de la key
#      11 for season in seasons_dict.keys():
# ---> 12     season_json = season_data(seasons_dict=seasons_dict, season_key=str(season), league_code=int(row['fm']), out_path=out_path)
#      14 # Partidos y diccionario con los IDs
#      15 matches = season_json.get('fixtures', {}).get('allMatches', {})
#
# Cell In[18], line 71, in season_data(seasons_dict, season_key, league_code, out_path)
#      68     season_link = seasons_dict[season_key]
#      70 # Leemos el link y guardado en JSON
# ---> 71 season_json = url_to_json(season_link)
#      72 with open(json_path, "w", encoding="utf-8") as f:
#      73     jsonlib.dump(season_json, f)
#
# Cell In[17], line 19, in url_to_json(url)
#      16 def url_to_json(url: str) -> dict:
#      18     out = requests.get(url).json()
# ---> 19     time.sleep(3)                           # Para garantir seguridad
#      21     return out
#
# KeyboardInterrupt:

# %%
dict_matches_urls
# Out:
# {'814657': 'https://www.fotmob.com/api/matchDetails?matchId=814657',
#  '814656': 'https://www.fotmob.com/api/matchDetails?matchId=814656',
#  '814658': 'https://www.fotmob.com/api/matchDetails?matchId=814658',
#  '814659': 'https://www.fotmob.com/api/matchDetails?matchId=814659',
#  '814662': 'https://www.fotmob.com/api/matchDetails?matchId=814662',
#  '814661': 'https://www.fotmob.com/api/matchDetails?matchId=814661',
#  '814660': 'https://www.fotmob.com/api/matchDetails?matchId=814660',
#  '814665': 'https://www.fotmob.com/api/matchDetails?matchId=814665',
#  '814666': 'https://www.fotmob.com/api/matchDetails?matchId=814666',
#  '814664': 'https://www.fotmob.com/api/matchDetails?matchId=814664',
#  '814668': 'https://www.fotmob.com/api/matchDetails?matchId=814668',
#  '814667': 'https://www.fotmob.com/api/matchDetails?matchId=814667',
#  '814671': 'https://www.fotmob.com/api/matchDetails?matchId=814671',
#  '814672': 'https://www.fotmob.com/api/matchDetails?matchId=814672',
#  '814670': 'https://www.fotmob.com/api/matchDetails?matchId=814670',
#  '827743': 'https://www.fotmob.com/api/matchDetails?matchId=827743',
#  '814674': 'https://www.fotmob.com/api/matchDetails?matchId=814674',
#  '814669': 'https://www.fotmob.com/api/matchDetails?matchId=814669',
#  '814675': 'https://www.fotmob.com/api/matchDetails?matchId=814675',
#  '814673': 'https://www.fotmob.com/api/matchDetails?matchId=814673',
#  '814676': 'https://www.fotmob.com/api/matchDetails?matchId=814676',
#  '814678': 'https://www.fotmob.com/api/matchDetails?matchId=814678',
#  '814677': 'https://www.fotmob.com/api/matchDetails?matchId=814677',
#  '814679': 'https://www.fotmob.com/api/matchDetails?matchId=814679',
#  '814680': 'https://www.fotmob.com/api/matchDetails?matchId=814680',
#  '814682': 'https://www.fotmob.com/api/matchDetails?matchId=814682',
#  '814681': 'https://www.fotmob.com/api/matchDetails?matchId=814681',
#  '814683': 'https://www.fotmob.com/api/matchDetails?matchId=814683',
#  '814684': 'https://www.fotmob.com/api/matchDetails?matchId=814684',
#  '814685': 'https://www.fotmob.com/api/matchDetails?matchId=814685',
#  '814686': 'https://www.fotmob.com/api/matchDetails?matchId=814686',
#  '814688': 'https://www.fotmob.com/api/matchDetails?matchId=814688',
#  '814687': 'https://www.fotmob.com/api/matchDetails?matchId=814687',
#  '814692': 'https://www.fotmob.com/api/matchDetails?matchId=814692',
#  '814695': 'https://www.fotmob.com/api/matchDetails?matchId=814695',
#  '814694': 'https://www.fotmob.com/api/matchDetails?matchId=814694',
#  '814690': 'https://www.fotmob.com/api/matchDetails?matchId=814690',
#  '814701': 'https://www.fotmob.com/api/matchDetails?matchId=814701',
#  '814697': 'https://www.fotmob.com/api/matchDetails?matchId=814697',
#  '814699': 'https://www.fotmob.com/api/matchDetails?matchId=814699',
#  '814717': 'https://www.fotmob.com/api/matchDetails?matchId=814717',
#  '814716': 'https://www.fotmob.com/api/matchDetails?matchId=814716',
#  '814718': 'https://www.fotmob.com/api/matchDetails?matchId=814718',
#  '814721': 'https://www.fotmob.com/api/matchDetails?matchId=814721',
#  '814722': 'https://www.fotmob.com/api/matchDetails?matchId=814722',
#  '814719': 'https://www.fotmob.com/api/matchDetails?matchId=814719',
#  '814720': 'https://www.fotmob.com/api/matchDetails?matchId=814720',
#  '814723': 'https://www.fotmob.com/api/matchDetails?matchId=814723',
#  '814725': 'https://www.fotmob.com/api/matchDetails?matchId=814725',
#  '814724': 'https://www.fotmob.com/api/matchDetails?matchId=814724',
#  '814727': 'https://www.fotmob.com/api/matchDetails?matchId=814727',
#  '814728': 'https://www.fotmob.com/api/matchDetails?matchId=814728',
#  '814732': 'https://www.fotmob.com/api/matchDetails?matchId=814732',
#  '814729': 'https://www.fotmob.com/api/matchDetails?matchId=814729',
#  '814731': 'https://www.fotmob.com/api/matchDetails?matchId=814731',
#  '814733': 'https://www.fotmob.com/api/matchDetails?matchId=814733',
#  '814726': 'https://www.fotmob.com/api/matchDetails?matchId=814726',
#  '814735': 'https://www.fotmob.com/api/matchDetails?matchId=814735',
#  '814734': 'https://www.fotmob.com/api/matchDetails?matchId=814734',
#  '814736': 'https://www.fotmob.com/api/matchDetails?matchId=814736',
#  '814744': 'https://www.fotmob.com/api/matchDetails?matchId=814744',
#  '814738': 'https://www.fotmob.com/api/matchDetails?matchId=814738',
#  '814737': 'https://www.fotmob.com/api/matchDetails?matchId=814737',
#  '814741': 'https://www.fotmob.com/api/matchDetails?matchId=814741',
#  '814742': 'https://www.fotmob.com/api/matchDetails?matchId=814742',
#  '814740': 'https://www.fotmob.com/api/matchDetails?matchId=814740',
#  '814739': 'https://www.fotmob.com/api/matchDetails?matchId=814739',
#  '814745': 'https://www.fotmob.com/api/matchDetails?matchId=814745',
#  '814743': 'https://www.fotmob.com/api/matchDetails?matchId=814743',
#  '814748': 'https://www.fotmob.com/api/matchDetails?matchId=814748',
#  '814753': 'https://www.fotmob.com/api/matchDetails?matchId=814753',
#  '814747': 'https://www.fotmob.com/api/matchDetails?matchId=814747',
#  '814751': 'https://www.fotmob.com/api/matchDetails?matchId=814751',
#  '814750': 'https://www.fotmob.com/api/matchDetails?matchId=814750',
#  '814752': 'https://www.fotmob.com/api/matchDetails?matchId=814752',
#  '814749': 'https://www.fotmob.com/api/matchDetails?matchId=814749',
#  '814754': 'https://www.fotmob.com/api/matchDetails?matchId=814754',
#  '814746': 'https://www.fotmob.com/api/matchDetails?matchId=814746',
#  '814755': 'https://www.fotmob.com/api/matchDetails?matchId=814755',
#  '814757': 'https://www.fotmob.com/api/matchDetails?matchId=814757',
#  '814758': 'https://www.fotmob.com/api/matchDetails?matchId=814758',
#  '814756': 'https://www.fotmob.com/api/matchDetails?matchId=814756',
#  '814759': 'https://www.fotmob.com/api/matchDetails?matchId=814759',
#  '814761': 'https://www.fotmob.com/api/matchDetails?matchId=814761',
#  '814762': 'https://www.fotmob.com/api/matchDetails?matchId=814762',
#  '814760': 'https://www.fotmob.com/api/matchDetails?matchId=814760',
#  '814763': 'https://www.fotmob.com/api/matchDetails?matchId=814763',
#  '814765': 'https://www.fotmob.com/api/matchDetails?matchId=814765',
#  '814764': 'https://www.fotmob.com/api/matchDetails?matchId=814764',
#  '814773': 'https://www.fotmob.com/api/matchDetails?matchId=814773',
#  '814771': 'https://www.fotmob.com/api/matchDetails?matchId=814771',
#  '816163': 'https://www.fotmob.com/api/matchDetails?matchId=816163',
#  '814772': 'https://www.fotmob.com/api/matchDetails?matchId=814772',
#  '814776': 'https://www.fotmob.com/api/matchDetails?matchId=814776',
#  '814774': 'https://www.fotmob.com/api/matchDetails?matchId=814774',
#  '814775': 'https://www.fotmob.com/api/matchDetails?matchId=814775',
#  '814784': 'https://www.fotmob.com/api/matchDetails?matchId=814784',
#  '814783': 'https://www.fotmob.com/api/matchDetails?matchId=814783',
#  '814781': 'https://www.fotmob.com/api/matchDetails?matchId=814781',
#  '814786': 'https://www.fotmob.com/api/matchDetails?matchId=814786',
#  '814789': 'https://www.fotmob.com/api/matchDetails?matchId=814789',
#  '814785': 'https://www.fotmob.com/api/matchDetails?matchId=814785',
#  '814790': 'https://www.fotmob.com/api/matchDetails?matchId=814790',
#  '814803': 'https://www.fotmob.com/api/matchDetails?matchId=814803',
#  '814801': 'https://www.fotmob.com/api/matchDetails?matchId=814801',
#  '814809': 'https://www.fotmob.com/api/matchDetails?matchId=814809',
#  '814812': 'https://www.fotmob.com/api/matchDetails?matchId=814812',
#  '814816': 'https://www.fotmob.com/api/matchDetails?matchId=814816',
#  '814819': 'https://www.fotmob.com/api/matchDetails?matchId=814819',
#  '814821': 'https://www.fotmob.com/api/matchDetails?matchId=814821',
#  '814822': 'https://www.fotmob.com/api/matchDetails?matchId=814822',
#  '814825': 'https://www.fotmob.com/api/matchDetails?matchId=814825',
#  '814832': 'https://www.fotmob.com/api/matchDetails?matchId=814832',
#  '814829': 'https://www.fotmob.com/api/matchDetails?matchId=814829',
#  '814827': 'https://www.fotmob.com/api/matchDetails?matchId=814827',
#  '814833': 'https://www.fotmob.com/api/matchDetails?matchId=814833',
#  '814830': 'https://www.fotmob.com/api/matchDetails?matchId=814830',
#  '814834': 'https://www.fotmob.com/api/matchDetails?matchId=814834',
#  '814846': 'https://www.fotmob.com/api/matchDetails?matchId=814846',
#  '814844': 'https://www.fotmob.com/api/matchDetails?matchId=814844',
#  '814848': 'https://www.fotmob.com/api/matchDetails?matchId=814848',
#  '814847': 'https://www.fotmob.com/api/matchDetails?matchId=814847',
#  '814852': 'https://www.fotmob.com/api/matchDetails?matchId=814852',
#  '814840': 'https://www.fotmob.com/api/matchDetails?matchId=814840',
#  '814850': 'https://www.fotmob.com/api/matchDetails?matchId=814850',
#  '814845': 'https://www.fotmob.com/api/matchDetails?matchId=814845',
#  '814842': 'https://www.fotmob.com/api/matchDetails?matchId=814842',
#  '814843': 'https://www.fotmob.com/api/matchDetails?matchId=814843',
#  '814864': 'https://www.fotmob.com/api/matchDetails?matchId=814864',
#  '814856': 'https://www.fotmob.com/api/matchDetails?matchId=814856',
#  '814858': 'https://www.fotmob.com/api/matchDetails?matchId=814858',
#  '814862': 'https://www.fotmob.com/api/matchDetails?matchId=814862',
#  '814868': 'https://www.fotmob.com/api/matchDetails?matchId=814868',
#  '814860': 'https://www.fotmob.com/api/matchDetails?matchId=814860',
#  '814857': 'https://www.fotmob.com/api/matchDetails?matchId=814857',
#  '814865': 'https://www.fotmob.com/api/matchDetails?matchId=814865',
#  '814861': 'https://www.fotmob.com/api/matchDetails?matchId=814861',
#  '814863': 'https://www.fotmob.com/api/matchDetails?matchId=814863',
#  '814887': 'https://www.fotmob.com/api/matchDetails?matchId=814887',
#  '814875': 'https://www.fotmob.com/api/matchDetails?matchId=814875',
#  '814882': 'https://www.fotmob.com/api/matchDetails?matchId=814882',
#  '814878': 'https://www.fotmob.com/api/matchDetails?matchId=814878',
#  '814871': 'https://www.fotmob.com/api/matchDetails?matchId=814871',
#  '814873': 'https://www.fotmob.com/api/matchDetails?matchId=814873',
#  '814874': 'https://www.fotmob.com/api/matchDetails?matchId=814874',
#  '814884': 'https://www.fotmob.com/api/matchDetails?matchId=814884',
#  '814870': 'https://www.fotmob.com/api/matchDetails?matchId=814870',
#  '814872': 'https://www.fotmob.com/api/matchDetails?matchId=814872',
#  '814897': 'https://www.fotmob.com/api/matchDetails?matchId=814897',
#  '814893': 'https://www.fotmob.com/api/matchDetails?matchId=814893',
#  '814890': 'https://www.fotmob.com/api/matchDetails?matchId=814890',
#  '814895': 'https://www.fotmob.com/api/matchDetails?matchId=814895',
#  '814894': 'https://www.fotmob.com/api/matchDetails?matchId=814894',
#  '814896': 'https://www.fotmob.com/api/matchDetails?matchId=814896',
#  '814891': 'https://www.fotmob.com/api/matchDetails?matchId=814891',
#  '814899': 'https://www.fotmob.com/api/matchDetails?matchId=814899',
#  '814898': 'https://www.fotmob.com/api/matchDetails?matchId=814898',
#  '814892': 'https://www.fotmob.com/api/matchDetails?matchId=814892',
#  '814908': 'https://www.fotmob.com/api/matchDetails?matchId=814908',
#  '814913': 'https://www.fotmob.com/api/matchDetails?matchId=814913',
#  '814906': 'https://www.fotmob.com/api/matchDetails?matchId=814906',
#  '814900': 'https://www.fotmob.com/api/matchDetails?matchId=814900',
#  '814903': 'https://www.fotmob.com/api/matchDetails?matchId=814903',
#  '814915': 'https://www.fotmob.com/api/matchDetails?matchId=814915',
#  '814912': 'https://www.fotmob.com/api/matchDetails?matchId=814912',
#  '814901': 'https://www.fotmob.com/api/matchDetails?matchId=814901',
#  '814904': 'https://www.fotmob.com/api/matchDetails?matchId=814904',
#  '814914': 'https://www.fotmob.com/api/matchDetails?matchId=814914',
#  '814923': 'https://www.fotmob.com/api/matchDetails?matchId=814923',
#  '814918': 'https://www.fotmob.com/api/matchDetails?matchId=814918',
#  '814920': 'https://www.fotmob.com/api/matchDetails?matchId=814920',
#  '814917': 'https://www.fotmob.com/api/matchDetails?matchId=814917',
#  '814916': 'https://www.fotmob.com/api/matchDetails?matchId=814916',
#  '814919': 'https://www.fotmob.com/api/matchDetails?matchId=814919',
#  '814922': 'https://www.fotmob.com/api/matchDetails?matchId=814922',
#  '814924': 'https://www.fotmob.com/api/matchDetails?matchId=814924',
#  '814921': 'https://www.fotmob.com/api/matchDetails?matchId=814921',
#  '814925': 'https://www.fotmob.com/api/matchDetails?matchId=814925',
#  '814928': 'https://www.fotmob.com/api/matchDetails?matchId=814928',
#  '814933': 'https://www.fotmob.com/api/matchDetails?matchId=814933',
#  '814935': 'https://www.fotmob.com/api/matchDetails?matchId=814935',
#  '814931': 'https://www.fotmob.com/api/matchDetails?matchId=814931',
#  '814930': 'https://www.fotmob.com/api/matchDetails?matchId=814930',
#  '814927': 'https://www.fotmob.com/api/matchDetails?matchId=814927',
#  '814929': 'https://www.fotmob.com/api/matchDetails?matchId=814929',
#  '814934': 'https://www.fotmob.com/api/matchDetails?matchId=814934',
#  '814926': 'https://www.fotmob.com/api/matchDetails?matchId=814926',
#  '814932': 'https://www.fotmob.com/api/matchDetails?matchId=814932',
#  '814938': 'https://www.fotmob.com/api/matchDetails?matchId=814938',
#  '814936': 'https://www.fotmob.com/api/matchDetails?matchId=814936',
#  '814940': 'https://www.fotmob.com/api/matchDetails?matchId=814940',
#  '814937': 'https://www.fotmob.com/api/matchDetails?matchId=814937',
#  '814945': 'https://www.fotmob.com/api/matchDetails?matchId=814945',
#  '814939': 'https://www.fotmob.com/api/matchDetails?matchId=814939',
#  '814941': 'https://www.fotmob.com/api/matchDetails?matchId=814941',
#  '814943': 'https://www.fotmob.com/api/matchDetails?matchId=814943',
#  '814944': 'https://www.fotmob.com/api/matchDetails?matchId=814944',
#  '814946': 'https://www.fotmob.com/api/matchDetails?matchId=814946',
#  '814950': 'https://www.fotmob.com/api/matchDetails?matchId=814950',
#  '814953': 'https://www.fotmob.com/api/matchDetails?matchId=814953',
#  '814951': 'https://www.fotmob.com/api/matchDetails?matchId=814951',
#  '814947': 'https://www.fotmob.com/api/matchDetails?matchId=814947',
#  '814955': 'https://www.fotmob.com/api/matchDetails?matchId=814955',
#  '814952': 'https://www.fotmob.com/api/matchDetails?matchId=814952',
#  '827744': 'https://www.fotmob.com/api/matchDetails?matchId=827744',
#  '814949': 'https://www.fotmob.com/api/matchDetails?matchId=814949',
#  '814954': 'https://www.fotmob.com/api/matchDetails?matchId=814954',
#  '814948': 'https://www.fotmob.com/api/matchDetails?matchId=814948',
#  '814960': 'https://www.fotmob.com/api/matchDetails?matchId=814960',
#  '814957': 'https://www.fotmob.com/api/matchDetails?matchId=814957',
#  '814958': 'https://www.fotmob.com/api/matchDetails?matchId=814958',
#  '814965': 'https://www.fotmob.com/api/matchDetails?matchId=814965',
#  '814959': 'https://www.fotmob.com/api/matchDetails?matchId=814959',
#  '814956': 'https://www.fotmob.com/api/matchDetails?matchId=814956',
#  '814961': 'https://www.fotmob.com/api/matchDetails?matchId=814961',
#  '814963': 'https://www.fotmob.com/api/matchDetails?matchId=814963',
#  '814964': 'https://www.fotmob.com/api/matchDetails?matchId=814964',
#  '814962': 'https://www.fotmob.com/api/matchDetails?matchId=814962',
#  '814730': 'https://www.fotmob.com/api/matchDetails?matchId=814730',
#  '814795': 'https://www.fotmob.com/api/matchDetails?matchId=814795',
#  '814976': 'https://www.fotmob.com/api/matchDetails?matchId=814976',
#  '814969': 'https://www.fotmob.com/api/matchDetails?matchId=814969',
#  '814974': 'https://www.fotmob.com/api/matchDetails?matchId=814974',
#  '814972': 'https://www.fotmob.com/api/matchDetails?matchId=814972',
#  '814973': 'https://www.fotmob.com/api/matchDetails?matchId=814973',
#  '814971': 'https://www.fotmob.com/api/matchDetails?matchId=814971',
#  '814970': 'https://www.fotmob.com/api/matchDetails?matchId=814970',
#  '814968': 'https://www.fotmob.com/api/matchDetails?matchId=814968',
#  '814967': 'https://www.fotmob.com/api/matchDetails?matchId=814967',
#  '814975': 'https://www.fotmob.com/api/matchDetails?matchId=814975',
#  '814980': 'https://www.fotmob.com/api/matchDetails?matchId=814980',
#  '814981': 'https://www.fotmob.com/api/matchDetails?matchId=814981',
#  '814986': 'https://www.fotmob.com/api/matchDetails?matchId=814986',
#  '814985': 'https://www.fotmob.com/api/matchDetails?matchId=814985',
#  '814977': 'https://www.fotmob.com/api/matchDetails?matchId=814977',
#  '814984': 'https://www.fotmob.com/api/matchDetails?matchId=814984',
#  '814982': 'https://www.fotmob.com/api/matchDetails?matchId=814982',
#  '814983': 'https://www.fotmob.com/api/matchDetails?matchId=814983',
#  '814978': 'https://www.fotmob.com/api/matchDetails?matchId=814978',
#  '814979': 'https://www.fotmob.com/api/matchDetails?matchId=814979',
#  '814989': 'https://www.fotmob.com/api/matchDetails?matchId=814989',
#  '814994': 'https://www.fotmob.com/api/matchDetails?matchId=814994',
#  '814990': 'https://www.fotmob.com/api/matchDetails?matchId=814990',
#  '814987': 'https://www.fotmob.com/api/matchDetails?matchId=814987',
#  '814993': 'https://www.fotmob.com/api/matchDetails?matchId=814993',
#  '814995': 'https://www.fotmob.com/api/matchDetails?matchId=814995',
#  '814992': 'https://www.fotmob.com/api/matchDetails?matchId=814992',
#  '814996': 'https://www.fotmob.com/api/matchDetails?matchId=814996',
#  '814991': 'https://www.fotmob.com/api/matchDetails?matchId=814991',
#  '814988': 'https://www.fotmob.com/api/matchDetails?matchId=814988',
#  '815000': 'https://www.fotmob.com/api/matchDetails?matchId=815000',
#  '815004': 'https://www.fotmob.com/api/matchDetails?matchId=815004',
#  '815001': 'https://www.fotmob.com/api/matchDetails?matchId=815001',
#  '815003': 'https://www.fotmob.com/api/matchDetails?matchId=815003',
#  '814998': 'https://www.fotmob.com/api/matchDetails?matchId=814998',
#  '815005': 'https://www.fotmob.com/api/matchDetails?matchId=815005',
#  '814997': 'https://www.fotmob.com/api/matchDetails?matchId=814997',
#  '815002': 'https://www.fotmob.com/api/matchDetails?matchId=815002',
#  '815006': 'https://www.fotmob.com/api/matchDetails?matchId=815006',
#  '814999': 'https://www.fotmob.com/api/matchDetails?matchId=814999',
#  '815019': 'https://www.fotmob.com/api/matchDetails?matchId=815019',
#  '815015': 'https://www.fotmob.com/api/matchDetails?matchId=815015',
#  '815016': 'https://www.fotmob.com/api/matchDetails?matchId=815016',
#  '815024': 'https://www.fotmob.com/api/matchDetails?matchId=815024',
#  '815014': 'https://www.fotmob.com/api/matchDetails?matchId=815014',
#  '815007': 'https://www.fotmob.com/api/matchDetails?matchId=815007',
#  '815021': 'https://www.fotmob.com/api/matchDetails?matchId=815021',
#  '815011': 'https://www.fotmob.com/api/matchDetails?matchId=815011',
#  '815012': 'https://www.fotmob.com/api/matchDetails?matchId=815012',
#  '815009': 'https://www.fotmob.com/api/matchDetails?matchId=815009',
#  '815046': 'https://www.fotmob.com/api/matchDetails?matchId=815046',
#  '815041': 'https://www.fotmob.com/api/matchDetails?matchId=815041',
#  '815027': 'https://www.fotmob.com/api/matchDetails?matchId=815027',
#  '815029': 'https://www.fotmob.com/api/matchDetails?matchId=815029',
#  '816462': 'https://www.fotmob.com/api/matchDetails?matchId=816462',
#  '815035': 'https://www.fotmob.com/api/matchDetails?matchId=815035',
#  '815038': 'https://www.fotmob.com/api/matchDetails?matchId=815038',
#  '815043': 'https://www.fotmob.com/api/matchDetails?matchId=815043',
#  '815048': 'https://www.fotmob.com/api/matchDetails?matchId=815048',
#  '815033': 'https://www.fotmob.com/api/matchDetails?matchId=815033',
#  '815056': 'https://www.fotmob.com/api/matchDetails?matchId=815056',
#  '815067': 'https://www.fotmob.com/api/matchDetails?matchId=815067',
#  '815061': 'https://www.fotmob.com/api/matchDetails?matchId=815061',
#  '815059': 'https://www.fotmob.com/api/matchDetails?matchId=815059',
#  '815054': 'https://www.fotmob.com/api/matchDetails?matchId=815054',
#  '815051': 'https://www.fotmob.com/api/matchDetails?matchId=815051',
#  '815071': 'https://www.fotmob.com/api/matchDetails?matchId=815071',
#  '815073': 'https://www.fotmob.com/api/matchDetails?matchId=815073',
#  '815065': 'https://www.fotmob.com/api/matchDetails?matchId=815065',
#  '815069': 'https://www.fotmob.com/api/matchDetails?matchId=815069',
#  '815095': 'https://www.fotmob.com/api/matchDetails?matchId=815095',
#  '815091': 'https://www.fotmob.com/api/matchDetails?matchId=815091',
#  '816164': 'https://www.fotmob.com/api/matchDetails?matchId=816164',
#  '815085': 'https://www.fotmob.com/api/matchDetails?matchId=815085',
#  '815098': 'https://www.fotmob.com/api/matchDetails?matchId=815098',
#  '815079': 'https://www.fotmob.com/api/matchDetails?matchId=815079',
#  '815083': 'https://www.fotmob.com/api/matchDetails?matchId=815083',
#  '815088': 'https://www.fotmob.com/api/matchDetails?matchId=815088',
#  '815092': 'https://www.fotmob.com/api/matchDetails?matchId=815092',
#  '815082': 'https://www.fotmob.com/api/matchDetails?matchId=815082',
#  '815117': 'https://www.fotmob.com/api/matchDetails?matchId=815117',
#  '815140': 'https://www.fotmob.com/api/matchDetails?matchId=815140',
#  '815120': 'https://www.fotmob.com/api/matchDetails?matchId=815120',
#  '815114': 'https://www.fotmob.com/api/matchDetails?matchId=815114',
#  '815131': 'https://www.fotmob.com/api/matchDetails?matchId=815131',
#  '815122': 'https://www.fotmob.com/api/matchDetails?matchId=815122',
#  '815107': 'https://www.fotmob.com/api/matchDetails?matchId=815107',
#  '815105': 'https://www.fotmob.com/api/matchDetails?matchId=815105',
#  '815110': 'https://www.fotmob.com/api/matchDetails?matchId=815110',
#  '815137': 'https://www.fotmob.com/api/matchDetails?matchId=815137'}
