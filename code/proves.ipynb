# %%
import os
import pandas as pd
import numpy as np
import json as jsonlib
from typing import Tuple
import re
from rapidfuzz import process, fuzz
import warnings
import shutil
from PIL import Image
import time

warnings.filterwarnings("ignore", category=pd.errors.PerformanceWarning)

from use.config import comps, desired_seasons, utils
from use.functions import create_slug, safe_div

from uni.unifier import *

league_data_unification(league_id=82, raw_data_path=r"c:\Users\xrosinach\Desktop\TFM\data\raw", clean_data_path=r"c:\Users\xrosinach\Desktop\TFM\data\clean", processed_data_path=r"c:\Users\xrosinach\Desktop\TFM\data\proc")
# Out:
# ...
# Starting data unification (Premier League)
#      - Data unification of season 2526
#         - League information unified
#         - Standings tables unified
#         - Teams and players stats in the matches
#         - Full season teams and players stats
#         - Images processed
#      - Data unification of season 2425
#         - League information unified
#         - Standings tables unified
#         - Teams and players stats in the matches
#         - Full season teams and players stats
#         - Images processed
#      - Data unification of season 2324
#         - League information unified
#         - Standings tables unified
#         - Teams and players stats in the matches
#         - Full season teams and players stats
#         - Images processed
#      - Data unification of season 2223
#         - League information unified
#         - Standings tables unified
#         - Teams and players stats in the matches
#         - Full season teams and players stats
# ...
